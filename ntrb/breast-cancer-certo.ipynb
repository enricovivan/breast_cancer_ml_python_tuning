# %%
# Import pandas
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# import roc_curve
from sklearn.metrics import roc_curve
from sklearn.model_selection import GridSearchCV

# %%
# Ler DB

df_certo = pd.read_csv("../app/database/breast-cancer-certo.csv")

df_certo.head(n=5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
# Copiar
df_copy = df_certo

# %%
# Transformar dados categóricos em valores
map = {"M" : 0, "B" : 1}

df_copy["diagnosis"] = df_copy["diagnosis"].map(map)

df_copy.head(n=5)
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302          0        17.99         10.38          122.80     1001.0
# 1    842517          0        20.57         17.77          132.90     1326.0
# 2  84300903          0        19.69         21.25          130.00     1203.0
# 3  84348301          0        11.42         20.38           77.58      386.1
# 4  84358402          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    ...  radius_worst  texture_worst  perimeter_worst  area_worst  \
# 0  ...         25.38          17.33           184.60      2019.0
# 1  ...         24.99          23.41           158.80      1956.0
# 2  ...         23.57          25.53           152.50      1709.0
# 3  ...         14.91          26.50            98.87       567.7
# 4  ...         22.54          16.67           152.20      1575.0
#
#    smoothness_worst  compactness_worst  concavity_worst  concave points_worst  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    symmetry_worst  fractal_dimension_worst
# 0          0.4601                  0.11890
# 1          0.2750                  0.08902
# 2          0.3613                  0.08758
# 3          0.6638                  0.17300
# 4          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
# Dropar id
df_copy = df_copy.drop(["id"], axis=1)

df_copy.head(n=5)
# Out:
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          0        17.99         10.38          122.80     1001.0
# 1          0        20.57         17.77          132.90     1326.0
# 2          0        19.69         21.25          130.00     1203.0
# 3          0        11.42         20.38           77.58      386.1
# 4          0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.2419  ...         25.38          17.33           184.60
# 1         0.1812  ...         24.99          23.41           158.80
# 2         0.2069  ...         23.57          25.53           152.50
# 3         0.2597  ...         14.91          26.50            98.87
# 4         0.1809  ...         22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 31 columns]

# %%
# Definir o target e a data

x = df_copy.drop(["diagnosis"], axis=1) #data
y = df_copy["diagnosis"] #target

# %%
# Normalizar os dados
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

x = pd.DataFrame(scaler.fit_transform(x), columns=x.columns)

x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0       0.521037      0.022658        0.545989   0.363733         0.593753
# 1       0.643144      0.272574        0.615783   0.501591         0.289880
# 2       0.601496      0.390260        0.595743   0.449417         0.514309
# 3       0.210090      0.360839        0.233501   0.102906         0.811321
# 4       0.629893      0.156578        0.630986   0.489290         0.430351
# ..           ...           ...             ...        ...              ...
# 564     0.690000      0.428813        0.678668   0.566490         0.526948
# 565     0.622320      0.626987        0.604036   0.474019         0.407782
# 566     0.455251      0.621238        0.445788   0.303118         0.288165
# 567     0.644564      0.663510        0.665538   0.475716         0.588336
# 568     0.036869      0.501522        0.028540   0.015907         0.000000
#
#      compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0            0.792037        0.703140             0.731113       0.686364
# 1            0.181768        0.203608             0.348757       0.379798
# 2            0.431017        0.462512             0.635686       0.509596
# 3            0.811361        0.565604             0.522863       0.776263
# 4            0.347893        0.463918             0.518390       0.378283
# ..                ...             ...                  ...            ...
# 564          0.296055        0.571462             0.690358       0.336364
# 565          0.257714        0.337395             0.486630       0.349495
# 566          0.254340        0.216753             0.263519       0.267677
# 567          0.790197        0.823336             0.755467       0.675253
# 568          0.074351        0.000000             0.000000       0.266162
#
#      fractal_dimension_mean  ...  radius_worst  texture_worst  \
# 0                  0.605518  ...      0.620776       0.141525
# 1                  0.141323  ...      0.606901       0.303571
# 2                  0.211247  ...      0.556386       0.360075
# 3                  1.000000  ...      0.248310       0.385928
# 4                  0.186816  ...      0.519744       0.123934
# ..                      ...  ...           ...            ...
# 564                0.132056  ...      0.623266       0.383262
# 565                0.113100  ...      0.560655       0.699094
# 566                0.137321  ...      0.393099       0.589019
# 567                0.425442  ...      0.633582       0.730277
# 568                0.187026  ...      0.054287       0.489072
#
#      perimeter_worst  area_worst  smoothness_worst  compactness_worst  \
# 0           0.668310    0.450698          0.601136           0.619292
# 1           0.539818    0.435214          0.347553           0.154563
# 2           0.508442    0.374508          0.483590           0.385375
# 3           0.241347    0.094008          0.915472           0.814012
# 4           0.506948    0.341575          0.437364           0.172415
# ..               ...         ...               ...                ...
# 564         0.576174    0.452664          0.461137           0.178527
# 565         0.520892    0.379915          0.300007           0.159997
# 566         0.379949    0.230731          0.282177           0.273705
# 567         0.668310    0.402035          0.619626           0.815758
# 568         0.043578    0.020497          0.124084           0.036043
#
#      concavity_worst  concave points_worst  symmetry_worst  \
# 0           0.568610              0.912027        0.598462
# 1           0.192971              0.639175        0.233590
# 2           0.359744              0.835052        0.403706
# 3           0.548642              0.884880        1.000000
# 4           0.319489              0.558419        0.157500
# ..               ...                   ...             ...
# 564         0.328035              0.761512        0.097575
# 565         0.256789              0.559450        0.198502
# 566         0.271805              0.487285        0.128721
# 567         0.749760              0.910653        0.497142
# 568         0.000000              0.000000        0.257441
#
#      fractal_dimension_worst
# 0                   0.418864
# 1                   0.222878
# 2                   0.213433
# 3                   0.773711
# 4                   0.142595
# ..                       ...
# 564                 0.105667
# 565                 0.074315
# 566                 0.151909
# 567                 0.452315
# 568                 0.100682
#
# [569 rows x 30 columns]

# %%
# Separando os dataframes em teste e treino
from sklearn.model_selection import train_test_split

random_state = 42

x_treino, x_teste, y_treino, y_teste = train_test_split(x,y, test_size=0.3, random_state=random_state)

print(len(x_treino))
print(len(x_teste))
# Out:
# 398
# 171

# %%
# Import verificação dos dados
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score, cohen_kappa_score

# %%
# Graficos
from sklearn.metrics import confusion_matrix

# %%
# Configurar as variveis
estimator = 30
learning = 0.03

# %% [markdown]
# # Adaboost

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada_boost = AdaBoostClassifier(n_estimators=estimator, learning_rate=learning, random_state=random_state)

model = ada_boost.fit(x_treino, y_treino)

ada_predict = model.predict(x_teste)

ada_predict_prob = ada_boost.predict_proba(x_teste)

# %% [markdown]
# ## Gráficos

# %%
sns.heatmap(confusion_matrix(y_teste, ada_predict), cmap='OrRd', annot=True, fmt='2.0f')
plt.title('SVC')
plt.ylabel('PREVISTO')
plt.xlabel('REAL')
plt.show()

# %%
ada_fp, ada_vp, lim1 = roc_curve(y_teste, ada_predict)
ada_curva_roc = roc_auc_score(y_teste,ada_predict)

plt.plot(ada_fp, ada_vp, marker=".", label="AdaBoost "+str(round(ada_curva_roc, 2)), color="red")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
ada_probs = ada_predict_prob[:,1]

ada_fp, ada_vp, lim1 = roc_curve(y_teste, ada_probs)

plt.plot(ada_fp, ada_vp, marker=".", label="AdaBoost", color="red")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# ## Resultado

# %%
acuracia = accuracy_score(y_teste,ada_predict)
precisao = precision_score(y_teste,ada_predict)
recall = recall_score(y_teste,ada_predict)
f1Score = f1_score(y_teste,ada_predict)
kappa = cohen_kappa_score(y_teste,ada_predict)

print('------ Adaboost ---------\n')
print(f'Acurácia: {acuracia}')
print(f'Precisão: {precisao}')
print(f'Recall ou Sensibilidade: {recall}')
print(f'F1-Score: {f1Score}')
print(f'Kappa: {kappa}')
# Out:
# ------ Adaboost ---------
#
# Acurácia: 0.9415204678362573
# Precisão: 0.9375
# Recall ou Sensibilidade: 0.9722222222222222
# F1-Score: 0.9545454545454546
# Kappa: 0.8726541554959786

# %% [markdown]
# ## GridSearchCV

# %%
parameters = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1.0],
    'algorithm': ['SAMME', 'SAMME.R'],
    'random_state': [42]
}

# %%
# aplicação do grid serach
grid_search = GridSearchCV(ada_boost, parameters, cv=5)
grid_search.fit(x_treino, y_treino)
# Out:
# GridSearchCV(cv=5,
#              estimator=AdaBoostClassifier(learning_rate=0.03, n_estimators=30,
#                                           random_state=42),
#              param_grid={'algorithm': ['SAMME', 'SAMME.R'],
#                          'learning_rate': [0.01, 0.1, 1.0],
#                          'n_estimators': [50, 100, 200], 'random_state': [42]})

# %%
best_params = grid_search.best_params_
print("Melhores parametros: ", best_params)
# Out:
# Melhores parametros:  {'algorithm': 'SAMME', 'learning_rate': 1.0, 'n_estimators': 50, 'random_state': 42}

# %%
adaboost_best_param = grid_search.best_estimator_
y_predAda = adaboost_best_param.predict(x_teste)

# %%
acuracia = accuracy_score(y_teste,y_predAda)
precisao = precision_score(y_teste,y_predAda)
recall = recall_score(y_teste,y_predAda)
f1Score = f1_score(y_teste,y_predAda)
kappa = cohen_kappa_score(y_teste,y_predAda)

print('------ Adaboost ---------\n')
print(f'Acurácia: {acuracia}')
print(f'Precisão: {precisao}')
print(f'Recall ou Sensibilidade: {recall}')
print(f'F1-Score: {f1Score}')
print(f'Kappa: {kappa}')
# Out:
# ------ Adaboost ---------
#
# Acurácia: 0.9707602339181286
# Precisão: 0.9813084112149533
# Recall ou Sensibilidade: 0.9722222222222222
# F1-Score: 0.9767441860465117
# Kappa: 0.9373764007910349

# %%
ada_fpG, ada_vpG, lim1G = roc_curve(y_teste, y_predAda)
ada_curva_rocG = roc_auc_score(y_teste,y_predAda)

plt.plot(ada_fpG, ada_vpG, marker=".", label="AdaBoost "+str(round(ada_curva_rocG, 2)), color="red")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
ada_probsG = grid_search.predict_proba(x_teste)[:,1]

ada_fpG, ada_vpG, lim1G = roc_curve(y_teste, ada_probsG)

plt.plot(ada_fpG, ada_vpG, marker=".", label="AdaBoost", color="red")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# # GBM

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gbm = GradientBoostingClassifier(n_estimators=estimator, learning_rate=learning, random_state=random_state)

model = gbm.fit(x_treino, y_treino)

gbm_predict = model.predict(x_teste)

gbm_predict_prob = gbm.predict_proba(x_teste)

# %% [markdown]
# ## Gráficos

# %%
sns.heatmap(confusion_matrix(y_teste, gbm_predict), cmap='OrRd', annot=True, fmt='2.0f')
plt.title('SVC')
plt.ylabel('PREVISTO')
plt.xlabel('REAL')
plt.show()

# %%
gbm_fp, gbm_vp, lim2 = roc_curve(y_teste, gbm_predict)
gbm_curva_roc = roc_auc_score(y_teste,gbm_predict)

plt.plot(gbm_fp, gbm_vp, marker=".", label="GBM "+str(round(gbm_curva_roc, 2)), color="green")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
gbm_probs = gbm_predict_prob[:,1]

gbm_fp, gbm_vp, lim2 = roc_curve(y_teste, gbm_probs)

plt.plot(gbm_fp, gbm_vp, marker=".", label="GBM", color="green")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# ## Resultado

# %%
acuracia = accuracy_score(y_teste,gbm_predict)
precisao = precision_score(y_teste,gbm_predict)
recall = recall_score(y_teste,gbm_predict)
f1Score = f1_score(y_teste,gbm_predict)
kappa = cohen_kappa_score(y_teste,gbm_predict)

print('------ GDM ---------\n')
print(f'Acurácia: {acuracia}')
print(f'Precisão: {precisao}')
print(f'Recall ou Sensibilidade: {recall}')
print(f'F1-Score: {f1Score}')
print(f'Kappa: {kappa}')
# Out:
# ------ GDM ---------
#
# Acurácia: 0.9707602339181286
# Precisão: 0.9813084112149533
# Recall ou Sensibilidade: 0.9722222222222222
# F1-Score: 0.9767441860465117
# Kappa: 0.9373764007910349

# %% [markdown]
# ## GridSearchCV

# %%
parameters = {
    'n_estimators': [100, 200, 300],
    'learning_rate': [0.01, 0.1, 0.2],
    'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'subsample': [0.8, 0.9, 1.0],
    'max_features': ['sqrt', 'log2', None],
    'random_state': [42]
}

# %%
grid_search = GridSearchCV(gbm, parameters, cv=5)
grid_search.fit(x_treino, y_treino)
# Out:
# GridSearchCV(cv=5,
#              estimator=GradientBoostingClassifier(learning_rate=0.03,
#                                                   n_estimators=30,
#                                                   random_state=42),
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 4, 5],
#                          'max_features': ['sqrt', 'log2', None],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [100, 200, 300], 'random_state': [42],
#                          'subsample': [0.8, 0.9, 1.0]})

# %%
best_params = grid_search.best_params_
print("Melhores parametros: ", best_params)
# Out:
# Melhores parametros:  {'learning_rate': 0.2, 'max_depth': 3, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 200, 'random_state': 42, 'subsample': 0.8}

# %%
gbm_best = grid_search.best_estimator_
y_pred_gbm = gbm_best.predict(x_teste)

# %%
acuracia = accuracy_score(y_teste,y_pred_gbm)
precisao = precision_score(y_teste,y_pred_gbm)
recall = recall_score(y_teste,y_pred_gbm)
f1Score = f1_score(y_teste,y_pred_gbm)
kappa = cohen_kappa_score(y_teste,y_pred_gbm)

print('---------- GBM ---------\n')
print(f'Acurácia: {acuracia}')
print(f'Precisão: {precisao}')
print(f'Recall ou Sensibilidade: {recall}')
print(f'F1-Score: {f1Score}')
print(f'Kappa: {kappa}')
# Out:
# ---------- GBM ---------
#
# Acurácia: 0.9766081871345029
# Precisão: 0.9727272727272728
# Recall ou Sensibilidade: 0.9907407407407407
# F1-Score: 0.981651376146789
# Kappa: 0.9494007989347537

# %%
gbm_fpG, gbm_vpG, lim2G = roc_curve(y_teste, y_pred_gbm)
gbm_curva_rocG = roc_auc_score(y_teste,y_pred_gbm)

plt.plot(gbm_fpG, gbm_vpG, marker=".", label="GBM "+str(round(gbm_curva_rocG, 2)), color="green")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
gbm_probsG = grid_search.predict_proba(x_teste)[:,1]

gbm_fpG, gbm_vpG, lim2G = roc_curve(y_teste, gbm_probsG)

plt.plot(gbm_fpG, gbm_vpG, marker=".", label="GBM", color="green")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# # Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=estimator, random_state=random_state)

model = rf.fit(x_treino, y_treino)

rf_predict = model.predict(x_teste)

rf_predict_prob = rf.predict_proba(x_teste)

# %% [markdown]
# ## Gráficos

# %%
sns.heatmap(confusion_matrix(y_teste, rf_predict), cmap='OrRd', annot=True, fmt='2.0f')
plt.title('SVC')
plt.ylabel('PREVISTO')
plt.xlabel('REAL')
plt.show()

# %%
rf_fp, rf_vp, lim3 = roc_curve(y_teste, rf_predict)
rf_curva_roc = roc_auc_score(y_teste,rf_predict)

plt.plot(rf_fp, rf_vp, marker=".", label="Random Forest "+str(round(rf_curva_roc, 2)), color="blue")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
rf_probs = rf_predict_prob[:,1]

rf_fp, rf_vp, lim3 = roc_curve(y_teste, rf_probs)

plt.plot(rf_fp, rf_vp, marker=".", label="Random Forest", color="blue")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# ## Resultado

# %%
acuracia = accuracy_score(y_teste,rf_predict)
precisao = precision_score(y_teste,rf_predict)
recall = recall_score(y_teste,rf_predict)
f1Score = f1_score(y_teste,rf_predict)
kappa = cohen_kappa_score(y_teste,rf_predict)

print('------ Random Forest ---------\n')
print(f'Acurácia: {acuracia}')
print(f'Precisão: {precisao}')
print(f'Recall ou Sensibilidade: {recall}')
print(f'F1-Score: {f1Score}')
print(f'Kappa: {kappa}')
# Out:
# ------ Random Forest ---------
#
# Acurácia: 0.9707602339181286
# Precisão: 0.963963963963964
# Recall ou Sensibilidade: 0.9907407407407407
# F1-Score: 0.9771689497716894
# Kappa: 0.9365397461589846

# %% [markdown]
# ## GridSearchCV

# %%
parameters = { 
    'n_estimators': [50, 100, 150],
    'max_depth': [3, 6, 9],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],
    'max_features': [1.0, 'sqrt', 'log2']
}

y_train_1d = y_treino.ravel()

# %%
grid_search = GridSearchCV(rf, parameters, cv=5, error_score='raise')
grid_search.fit(x_treino, y_train_1d)
# Out:
# GridSearchCV(cv=5, error_score='raise',
#              estimator=RandomForestClassifier(n_estimators=30, random_state=42),
#              param_grid={'max_depth': [3, 6, 9],
#                          'max_features': [1.0, 'sqrt', 'log2'],
#                          'min_samples_leaf': [1, 2, 4],
#                          'min_samples_split': [2, 5, 10],
#                          'n_estimators': [50, 100, 150]})

# %%
best_params = grid_search.best_params_
print("Melhores hiperparâmetros:", best_params)
# Out:
# Melhores hiperparâmetros: {'max_depth': 9, 'max_features': 'sqrt', 'min_samples_leaf': 2, 'min_samples_split': 2, 'n_estimators': 150}

# %%
rf_best = grid_search.best_estimator_
y_pred_rf = rf_best.predict(x_teste)

# %%
acuracia = accuracy_score(y_teste,y_pred_rf)
precisao = precision_score(y_teste,y_pred_rf)
recall = recall_score(y_teste,y_pred_rf)
f1Score = f1_score(y_teste,y_pred_rf)
kappa = cohen_kappa_score(y_teste,y_pred_rf)

print('---------- RandomForest ---------\n')
print(f'Acurácia: {acuracia}')
print(f'Precisão: {precisao}')
print(f'Recall ou Sensibilidade: {recall}')
print(f'F1-Score: {f1Score}')
print(f'Kappa: {kappa}')
# Out:
# ---------- RandomForest ---------
#
# Acurácia: 0.9707602339181286
# Precisão: 0.963963963963964
# Recall ou Sensibilidade: 0.9907407407407407
# F1-Score: 0.9771689497716894
# Kappa: 0.9365397461589846

# %%
rf_fpG, rf_vpG, lim3G = roc_curve(y_teste, y_pred_rf)
rf_curva_rocG = roc_auc_score(y_teste,y_pred_rf)

plt.plot(rf_fpG, rf_vpG, marker=".", label="Random Forest "+str(round(rf_curva_rocG, 2)), color="blue")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
rf_probsG = grid_search.predict_proba(x_teste)[:,1]

rf_fpG, rf_vpG, lim3G = roc_curve(y_teste, rf_probsG)

plt.plot(rf_fpG, rf_vpG, marker=".", label="Random Forest", color="blue")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# # CatBoost

# %%
from catboost import CatBoostClassifier

# %%
cat = CatBoostClassifier(n_estimators=estimator, learning_rate=learning, random_state=random_state)

model = cat.fit(x_treino, y_treino)

cat_predict = model.predict(x_teste)

cat_predict_prob = cat.predict_proba(x_teste)
# Out:
# 0:	learn: 0.6458382	total: 3.02ms	remaining: 87.5ms
# 1:	learn: 0.6040505	total: 5.22ms	remaining: 73.1ms
# 2:	learn: 0.5595114	total: 7.96ms	remaining: 71.7ms
# 3:	learn: 0.5247972	total: 11ms	remaining: 71.3ms
# 4:	learn: 0.4989183	total: 13.1ms	remaining: 65.5ms
# 5:	learn: 0.4676436	total: 15.5ms	remaining: 61.9ms
# 6:	learn: 0.4365765	total: 18.4ms	remaining: 60.5ms
# 7:	learn: 0.4082513	total: 20.9ms	remaining: 57.5ms
# 8:	learn: 0.3813392	total: 23.6ms	remaining: 55.1ms
# 9:	learn: 0.3589422	total: 26.3ms	remaining: 52.6ms
# 10:	learn: 0.3397529	total: 28.5ms	remaining: 49.3ms
# 11:	learn: 0.3242976	total: 31.4ms	remaining: 47ms
# 12:	learn: 0.3073592	total: 33.9ms	remaining: 44.4ms
# 13:	learn: 0.2923166	total: 36.7ms	remaining: 42ms
# 14:	learn: 0.2767856	total: 39.4ms	remaining: 39.4ms
# 15:	learn: 0.2629157	total: 41.5ms	remaining: 36.3ms
# 16:	learn: 0.2514883	total: 43.6ms	remaining: 33.4ms
# 17:	learn: 0.2395820	total: 46.7ms	remaining: 31.2ms
# 18:	learn: 0.2293391	total: 49.5ms	remaining: 28.7ms
# 19:	learn: 0.2181358	total: 52.9ms	remaining: 26.5ms
# 20:	learn: 0.2084001	total: 56ms	remaining: 24ms
# 21:	learn: 0.2015424	total: 58.6ms	remaining: 21.3ms
# 22:	learn: 0.1941102	total: 61.1ms	remaining: 18.6ms
# 23:	learn: 0.1856593	total: 64ms	remaining: 16ms
# 24:	learn: 0.1787708	total: 66.2ms	remaining: 13.2ms
# 25:	learn: 0.1732721	total: 68.2ms	remaining: 10.5ms
# 26:	learn: 0.1676077	total: 71.3ms	remaining: 7.92ms
# 27:	learn: 0.1612358	total: 74.3ms	remaining: 5.3ms
# 28:	learn: 0.1562858	total: 76.9ms	remaining: 2.65ms
# 29:	learn: 0.1508252	total: 79.3ms	remaining: 0us

# %% [markdown]
# ## Gráficos

# %%
sns.heatmap(confusion_matrix(y_teste, cat_predict), cmap='OrRd', annot=True, fmt='2.0f')
plt.title('SVC')
plt.ylabel('PREVISTO')
plt.xlabel('REAL')
plt.show()

# %%
cat_fp, cat_vp, lim4 = roc_curve(y_teste, cat_predict)
cat_curva_roc = roc_auc_score(y_teste,cat_predict)

plt.plot(cat_fp, cat_vp, marker=".", label="CatBoost "+str(round(gbm_curva_roc, 2)), color="yellow")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
cat_probs = cat_predict_prob[:,1]

cat_fp, cat_vp, lim4 = roc_curve(y_teste, cat_probs)

plt.plot(cat_fp, cat_vp, marker=".", label="CatBoost", color="yellow")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# ## Resultado

# %%
acuracia = accuracy_score(y_teste,cat_predict)
precisao = precision_score(y_teste,cat_predict)
recall = recall_score(y_teste,cat_predict)
f1Score = f1_score(y_teste,cat_predict)
cat_curva_rocG = roc_auc_score(y_teste,cat_predict)
kappa = cohen_kappa_score(y_teste,cat_predict)

print('------ CatBoost ---------\n')
print(f'Acurácia: {acuracia}')
print(f'Precisão: {precisao}')
print(f'Recall ou Sensibilidade: {recall}')
print(f'F1-Score: {f1Score}')
print(f'Kappa: {kappa}')
# Out:
# ------ CatBoost ---------
#
# Acurácia: 0.9649122807017544
# Precisão: 0.9636363636363636
# Recall ou Sensibilidade: 0.9814814814814815
# F1-Score: 0.9724770642201834
# Kappa: 0.9241011984021305

# %% [markdown]
# ## GridSearchCV

# %%
parameters = {
    'learning_rate': [0.01, 0.1],
    'depth': [4, 6, 8],
    'l2_leaf_reg': [3, 5, 7],
    'subsample': [0.8, 0.9],
    'colsample_bylevel': [0.8, 0.9],
    'border_count': [32, 64],
    'custom_metric': ['AUC', 'Logloss']
}

# %%
grid_search = GridSearchCV(cat, parameters, cv=5)
grid_search.fit(x_treino, y_treino)
# Out:
# 0:	learn: 0.6767610	total: 925us	remaining: 26.8ms
# 1:	learn: 0.6626988	total: 2ms	remaining: 28ms
# 2:	learn: 0.6470939	total: 2.81ms	remaining: 25.3ms
# 3:	learn: 0.6349261	total: 3.83ms	remaining: 24.9ms
# 4:	learn: 0.6231233	total: 4.85ms	remaining: 24.2ms
# 5:	learn: 0.6101168	total: 5.85ms	remaining: 23.4ms
# 6:	learn: 0.5963439	total: 6.81ms	remaining: 22.4ms
# 7:	learn: 0.5863540	total: 7.76ms	remaining: 21.3ms
# 8:	learn: 0.5743392	total: 8.61ms	remaining: 20.1ms
# 9:	learn: 0.5625332	total: 9.56ms	remaining: 19.1ms
# 10:	learn: 0.5526060	total: 10.5ms	remaining: 18.1ms
# 11:	learn: 0.5432408	total: 11.3ms	remaining: 16.9ms
# 12:	learn: 0.5340792	total: 12.1ms	remaining: 15.8ms
# 13:	learn: 0.5241914	total: 12.9ms	remaining: 14.7ms
# 14:	learn: 0.5122010	total: 13.8ms	remaining: 13.8ms
# 15:	learn: 0.5025731	total: 14.6ms	remaining: 12.8ms
# 16:	learn: 0.4929063	total: 15.4ms	remaining: 11.8ms
# 17:	learn: 0.4852209	total: 16.4ms	remaining: 10.9ms
# 18:	learn: 0.4774190	total: 17.5ms	remaining: 10.1ms
# 19:	learn: 0.4682730	total: 18.4ms	remaining: 9.22ms
# 20:	learn: 0.4601395	total: 19.4ms	remaining: 8.33ms
# 21:	learn: 0.4511224	total: 20.3ms	remaining: 7.39ms
# 22:	learn: 0.4425361	total: 21.2ms	remaining: 6.45ms
# 23:	learn: 0.4355619	total: 22.1ms	remaining: 5.51ms
# 24:	learn: 0.4271951	total: 23ms	remaining: 4.6ms
# 25:	learn: 0.4218955	total: 24.1ms	remaining: 3.7ms
# 26:	learn: 0.4142661	total: 25.1ms	remaining: 2.79ms
# 27:	learn: 0.4092105	total: 26ms	remaining: 1.86ms
# 28:	learn: 0.4023574	total: 27ms	remaining: 930us
# 29:	learn: 0.3954941	total: 27.9ms	remaining: 0us
# 0:	learn: 0.6764860	total: 1.08ms	remaining: 31.5ms
# 1:	learn: 0.6603144	total: 2.08ms	remaining: 29.2ms
# 2:	learn: 0.6454376	total: 2.97ms	remaining: 26.8ms
# 3:	learn: 0.6325657	total: 3.81ms	remaining: 24.8ms
# 4:	learn: 0.6191815	total: 4.65ms	remaining: 23.3ms
# 5:	learn: 0.6092299	total: 5.53ms	remaining: 22.1ms
# 6:	learn: 0.5954800	total: 6.51ms	remaining: 21.4ms
# 7:	learn: 0.5827940	total: 7.33ms	remaining: 20.2ms
# 8:	learn: 0.5689523	total: 8.21ms	remaining: 19.2ms
# 9:	learn: 0.5532977	total: 9.07ms	remaining: 18.1ms
# 10:	learn: 0.5440638	total: 10ms	remaining: 17.3ms
# 11:	learn: 0.5350591	total: 10.9ms	remaining: 16.4ms
# 12:	learn: 0.5243030	total: 11.9ms	remaining: 15.5ms
# 13:	learn: 0.5133922	total: 12.7ms	remaining: 14.5ms
# 14:	learn: 0.5019771	total: 13.6ms	remaining: 13.6ms
# 15:	learn: 0.4930391	total: 14.4ms	remaining: 12.6ms
# 16:	learn: 0.4845929	total: 15.4ms	remaining: 11.8ms
# 17:	learn: 0.4763760	total: 16.4ms	remaining: 10.9ms
# 18:	learn: 0.4673054	total: 17.5ms	remaining: 10.1ms
# 19:	learn: 0.4559570	total: 18.5ms	remaining: 9.25ms
# 20:	learn: 0.4468979	total: 19.5ms	remaining: 8.38ms
# 21:	learn: 0.4370576	total: 20.7ms	remaining: 7.51ms
# 22:	learn: 0.4277456	total: 21.6ms	remaining: 6.58ms
# 23:	learn: 0.4196775	total: 22.4ms	remaining: 5.6ms
# 24:	learn: 0.4136784	total: 23.5ms	remaining: 4.7ms
# 25:	learn: 0.4075322	total: 24.5ms	remaining: 3.76ms
# 26:	learn: 0.3992373	total: 25.3ms	remaining: 2.81ms
# 27:	learn: 0.3937774	total: 26.1ms	remaining: 1.86ms
# 28:	learn: 0.3861520	total: 27ms	remaining: 931us
# 29:	learn: 0.3808118	total: 27.8ms	remaining: 0us
# 0:	learn: 0.6782627	total: 986us	remaining: 28.6ms
# 1:	learn: 0.6635215	total: 1.78ms	remaining: 24.9ms
# 2:	learn: 0.6514111	total: 2.88ms	remaining: 25.9ms
# 3:	learn: 0.6396288	total: 3.81ms	remaining: 24.8ms
# 4:	learn: 0.6276362	total: 4.78ms	remaining: 23.9ms
# 5:	learn: 0.6175106	total: 5.77ms	remaining: 23.1ms
# 6:	learn: 0.6043432	total: 6.8ms	remaining: 22.3ms
# 7:	learn: 0.5927998	total: 7.67ms	remaining: 21.1ms
# 8:	learn: 0.5806246	total: 8.44ms	remaining: 19.7ms
# 9:	learn: 0.5679424	total: 9.25ms	remaining: 18.5ms
# 10:	learn: 0.5576278	total: 9.99ms	remaining: 17.3ms
# 11:	learn: 0.5489222	total: 10.8ms	remaining: 16.2ms
# 12:	learn: 0.5380805	total: 11.9ms	remaining: 15.5ms
# 13:	learn: 0.5278041	total: 13ms	remaining: 14.9ms
# 14:	learn: 0.5177996	total: 13.9ms	remaining: 13.9ms
# 15:	learn: 0.5070219	total: 14.7ms	remaining: 12.9ms
# 16:	learn: 0.4959765	total: 15.5ms	remaining: 11.9ms
# 17:	learn: 0.4884783	total: 16.3ms	remaining: 10.9ms
# 18:	learn: 0.4786438	total: 17.1ms	remaining: 9.88ms
# 19:	learn: 0.4675197	total: 17.8ms	remaining: 8.91ms
# 20:	learn: 0.4581770	total: 18.7ms	remaining: 8ms
# 21:	learn: 0.4496024	total: 19.6ms	remaining: 7.12ms
# 22:	learn: 0.4400266	total: 20.7ms	remaining: 6.29ms
# 23:	learn: 0.4327936	total: 21.6ms	remaining: 5.39ms
# 24:	learn: 0.4263551	total: 22.3ms	remaining: 4.47ms
# 25:	learn: 0.4185428	total: 23.2ms	remaining: 3.57ms
# 26:	learn: 0.4101214	total: 24.2ms	remaining: 2.69ms
# 27:	learn: 0.4044486	total: 25.2ms	remaining: 1.8ms
# 28:	learn: 0.3970727	total: 26.3ms	remaining: 908us
# 29:	learn: 0.3908921	total: 27.4ms	remaining: 0us
# 0:	learn: 0.6784547	total: 988us	remaining: 28.7ms
# 1:	learn: 0.6656764	total: 2.75ms	remaining: 38.5ms
# 2:	learn: 0.6538407	total: 3.92ms	remaining: 35.3ms
# 3:	learn: 0.6415394	total: 4.81ms	remaining: 31.2ms
# 4:	learn: 0.6297579	total: 5.71ms	remaining: 28.5ms
# 5:	learn: 0.6190624	total: 6.49ms	remaining: 26ms
# 6:	learn: 0.6056631	total: 7.25ms	remaining: 23.8ms
# 7:	learn: 0.5939941	total: 8.04ms	remaining: 22.1ms
# 8:	learn: 0.5805892	total: 8.98ms	remaining: 21ms
# 9:	learn: 0.5684760	total: 9.79ms	remaining: 19.6ms
# 10:	learn: 0.5580445	total: 10.6ms	remaining: 18.2ms
# 11:	learn: 0.5477892	total: 11.3ms	remaining: 17ms
# 12:	learn: 0.5394648	total: 12.2ms	remaining: 16ms
# 13:	learn: 0.5319501	total: 13.2ms	remaining: 15ms
# 14:	learn: 0.5232197	total: 14.1ms	remaining: 14.1ms
# 15:	learn: 0.5130904	total: 14.9ms	remaining: 13ms
# 16:	learn: 0.5031826	total: 15.7ms	remaining: 12ms
# 17:	learn: 0.4957367	total: 16.6ms	remaining: 11.1ms
# 18:	learn: 0.4867424	total: 17.5ms	remaining: 10.1ms
# 19:	learn: 0.4764426	total: 18.4ms	remaining: 9.18ms
# 20:	learn: 0.4675571	total: 19.3ms	remaining: 8.27ms
# 21:	learn: 0.4567603	total: 20.2ms	remaining: 7.36ms
# 22:	learn: 0.4475338	total: 21.1ms	remaining: 6.41ms
# 23:	learn: 0.4395640	total: 21.9ms	remaining: 5.47ms
# 24:	learn: 0.4322828	total: 22.8ms	remaining: 4.55ms
# 25:	learn: 0.4265725	total: 23.7ms	remaining: 3.64ms
# 26:	learn: 0.4187102	total: 24.7ms	remaining: 2.74ms
# 27:	learn: 0.4132495	total: 25.7ms	remaining: 1.83ms
# 28:	learn: 0.4050539	total: 26.7ms	remaining: 919us
# 29:	learn: 0.3987483	total: 27.5ms	remaining: 0us
# 0:	learn: 0.6778078	total: 1.2ms	remaining: 34.8ms
# 1:	learn: 0.6627604	total: 2.19ms	remaining: 30.7ms
# 2:	learn: 0.6484351	total: 2.98ms	remaining: 26.9ms
# 3:	learn: 0.6368865	total: 3.98ms	remaining: 25.9ms
# 4:	learn: 0.6248818	total: 4.78ms	remaining: 23.9ms
# 5:	learn: 0.6118950	total: 5.55ms	remaining: 22.2ms
# 6:	learn: 0.5979148	total: 6.59ms	remaining: 21.7ms
# 7:	learn: 0.5864747	total: 7.41ms	remaining: 20.4ms
# 8:	learn: 0.5765062	total: 8.23ms	remaining: 19.2ms
# 9:	learn: 0.5626248	total: 9.01ms	remaining: 18ms
# 10:	learn: 0.5522067	total: 9.89ms	remaining: 17.1ms
# 11:	learn: 0.5415066	total: 10.8ms	remaining: 16.2ms
# 12:	learn: 0.5336251	total: 11.7ms	remaining: 15.2ms
# 13:	learn: 0.5225430	total: 12.5ms	remaining: 14.3ms
# 14:	learn: 0.5145983	total: 13.3ms	remaining: 13.3ms
# 15:	learn: 0.5044969	total: 14.3ms	remaining: 12.5ms
# 16:	learn: 0.4950533	total: 15.3ms	remaining: 11.7ms
# 17:	learn: 0.4884166	total: 16.2ms	remaining: 10.8ms
# 18:	learn: 0.4800332	total: 16.9ms	remaining: 9.8ms
# 19:	learn: 0.4683739	total: 17.7ms	remaining: 8.85ms
# 20:	learn: 0.4587315	total: 18.5ms	remaining: 7.94ms
# 21:	learn: 0.4492621	total: 19.3ms	remaining: 7.03ms
# 22:	learn: 0.4403275	total: 20.4ms	remaining: 6.22ms
# 23:	learn: 0.4321578	total: 21.6ms	remaining: 5.4ms
# 24:	learn: 0.4241380	total: 22.8ms	remaining: 4.55ms
# 25:	learn: 0.4186572	total: 24ms	remaining: 3.69ms
# 26:	learn: 0.4104321	total: 25ms	remaining: 2.78ms
# 27:	learn: 0.4036372	total: 25.9ms	remaining: 1.85ms
# 28:	learn: 0.3962794	total: 26.8ms	remaining: 923us
# 29:	learn: 0.3910610	total: 27.6ms	remaining: 0us
# 0:	learn: 0.6767610	total: 940us	remaining: 27.3ms
# 1:	learn: 0.6616013	total: 1.8ms	remaining: 25.2ms
# 2:	learn: 0.6460494	total: 2.59ms	remaining: 23.3ms
# 3:	learn: 0.6338988	total: 3.37ms	remaining: 21.9ms
# 4:	learn: 0.6221374	total: 4.15ms	remaining: 20.8ms
# 5:	learn: 0.6112002	total: 4.93ms	remaining: 19.7ms
# 6:	learn: 0.5973998	total: 5.71ms	remaining: 18.8ms
# 7:	learn: 0.5859713	total: 6.49ms	remaining: 17.9ms
# 8:	learn: 0.5740127	total: 7.46ms	remaining: 17.4ms
# 9:	learn: 0.5622127	total: 8.55ms	remaining: 17.1ms
# 10:	learn: 0.5522435	total: 9.36ms	remaining: 16.2ms
# 11:	learn: 0.5428801	total: 10.3ms	remaining: 15.5ms
# 12:	learn: 0.5356665	total: 11.3ms	remaining: 14.8ms
# 13:	learn: 0.5257748	total: 12.3ms	remaining: 14.1ms
# 14:	learn: 0.5137456	total: 13.3ms	remaining: 13.3ms
# 15:	learn: 0.5040730	total: 14.4ms	remaining: 12.6ms
# 16:	learn: 0.4953579	total: 15.3ms	remaining: 11.7ms
# 17:	learn: 0.4872465	total: 16.1ms	remaining: 10.7ms
# 18:	learn: 0.4791142	total: 16.9ms	remaining: 9.77ms
# 19:	learn: 0.4699301	total: 17.7ms	remaining: 8.83ms
# 20:	learn: 0.4611615	total: 18.5ms	remaining: 7.95ms
# 21:	learn: 0.4521230	total: 19.5ms	remaining: 7.09ms
# 22:	learn: 0.4434991	total: 20.5ms	remaining: 6.24ms
# 23:	learn: 0.4365034	total: 21.4ms	remaining: 5.36ms
# 24:	learn: 0.4303406	total: 22.4ms	remaining: 4.48ms
# 25:	learn: 0.4233350	total: 23.3ms	remaining: 3.58ms
# 26:	learn: 0.4148706	total: 24.1ms	remaining: 2.68ms
# 27:	learn: 0.4098134	total: 24.9ms	remaining: 1.78ms
# 28:	learn: 0.4029631	total: 25.8ms	remaining: 888us
# 29:	learn: 0.3961063	total: 26.6ms	remaining: 0us
# 0:	learn: 0.6764860	total: 1.06ms	remaining: 30.8ms
# 1:	learn: 0.6603144	total: 1.9ms	remaining: 26.6ms
# 2:	learn: 0.6462663	total: 2.76ms	remaining: 24.8ms
# 3:	learn: 0.6340200	total: 3.62ms	remaining: 23.5ms
# 4:	learn: 0.6205984	total: 4.85ms	remaining: 24.3ms
# 5:	learn: 0.6106253	total: 5.82ms	remaining: 23.3ms
# 6:	learn: 0.5964349	total: 6.84ms	remaining: 22.5ms
# 7:	learn: 0.5837314	total: 7.76ms	remaining: 21.3ms
# 8:	learn: 0.5681689	total: 8.64ms	remaining: 20.2ms
# 9:	learn: 0.5525361	total: 9.55ms	remaining: 19.1ms
# 10:	learn: 0.5425850	total: 10.8ms	remaining: 18.7ms
# 11:	learn: 0.5335675	total: 11.9ms	remaining: 17.8ms
# 12:	learn: 0.5256933	total: 13.1ms	remaining: 17.1ms
# 13:	learn: 0.5153338	total: 13.9ms	remaining: 15.9ms
# 14:	learn: 0.5038261	total: 14.8ms	remaining: 14.8ms
# 15:	learn: 0.4948386	total: 15.7ms	remaining: 13.7ms
# 16:	learn: 0.4847489	total: 16.5ms	remaining: 12.6ms
# 17:	learn: 0.4765470	total: 17.5ms	remaining: 11.7ms
# 18:	learn: 0.4673546	total: 18.4ms	remaining: 10.7ms
# 19:	learn: 0.4560053	total: 19.4ms	remaining: 9.72ms
# 20:	learn: 0.4463423	total: 20.5ms	remaining: 8.78ms
# 21:	learn: 0.4364949	total: 21.5ms	remaining: 7.83ms
# 22:	learn: 0.4272290	total: 22.4ms	remaining: 6.83ms
# 23:	learn: 0.4191888	total: 23.4ms	remaining: 5.85ms
# 24:	learn: 0.4124389	total: 24.8ms	remaining: 4.96ms
# 25:	learn: 0.4063002	total: 25.7ms	remaining: 3.96ms
# 26:	learn: 0.3980064	total: 26.6ms	remaining: 2.96ms
# 27:	learn: 0.3925540	total: 27.7ms	remaining: 1.98ms
# 28:	learn: 0.3849294	total: 38.7ms	remaining: 1.34ms
# 29:	learn: 0.3796121	total: 40ms	remaining: 0us
# 0:	learn: 0.6773672	total: 1.11ms	remaining: 32.2ms
# 1:	learn: 0.6607385	total: 2.08ms	remaining: 29.1ms
# 2:	learn: 0.6486819	total: 2.95ms	remaining: 26.5ms
# 3:	learn: 0.6369594	total: 3.73ms	remaining: 24.2ms
# 4:	learn: 0.6250183	total: 4.57ms	remaining: 22.9ms
# 5:	learn: 0.6149339	total: 5.47ms	remaining: 21.9ms
# 6:	learn: 0.6018217	total: 6.5ms	remaining: 21.4ms
# 7:	learn: 0.5903303	total: 7.42ms	remaining: 20.4ms
# 8:	learn: 0.5773390	total: 8.37ms	remaining: 19.5ms
# 9:	learn: 0.5647372	total: 9.28ms	remaining: 18.6ms
# 10:	learn: 0.5551201	total: 10.3ms	remaining: 17.7ms
# 11:	learn: 0.5464826	total: 11.1ms	remaining: 16.6ms
# 12:	learn: 0.5356865	total: 12ms	remaining: 15.7ms
# 13:	learn: 0.5254553	total: 12.8ms	remaining: 14.7ms
# 14:	learn: 0.5155086	total: 13.8ms	remaining: 13.8ms
# 15:	learn: 0.5047726	total: 14.8ms	remaining: 13ms
# 16:	learn: 0.4937752	total: 15.7ms	remaining: 12ms
# 17:	learn: 0.4863111	total: 16.7ms	remaining: 11.1ms
# 18:	learn: 0.4765190	total: 17.6ms	remaining: 10.2ms
# 19:	learn: 0.4668401	total: 18.5ms	remaining: 9.25ms
# 20:	learn: 0.4575113	total: 19.4ms	remaining: 8.32ms
# 21:	learn: 0.4483659	total: 20.2ms	remaining: 7.36ms
# 22:	learn: 0.4388248	total: 21.4ms	remaining: 6.5ms
# 23:	learn: 0.4315360	total: 22.4ms	remaining: 5.6ms
# 24:	learn: 0.4248072	total: 23.3ms	remaining: 4.65ms
# 25:	learn: 0.4170303	total: 24.2ms	remaining: 3.72ms
# 26:	learn: 0.4086624	total: 25.1ms	remaining: 2.79ms
# 27:	learn: 0.4030067	total: 26.2ms	remaining: 1.87ms
# 28:	learn: 0.3956767	total: 27ms	remaining: 932us
# 29:	learn: 0.3895500	total: 27.9ms	remaining: 0us
# 0:	learn: 0.6763940	total: 1.14ms	remaining: 33.1ms
# 1:	learn: 0.6636343	total: 2ms	remaining: 27.9ms
# 2:	learn: 0.6486358	total: 2.81ms	remaining: 25.3ms
# 3:	learn: 0.6364597	total: 3.62ms	remaining: 23.5ms
# 4:	learn: 0.6248017	total: 4.57ms	remaining: 22.8ms
# 5:	learn: 0.6142175	total: 5.51ms	remaining: 22ms
# 6:	learn: 0.6013370	total: 6.44ms	remaining: 21.2ms
# 7:	learn: 0.5897712	total: 7.41ms	remaining: 20.4ms
# 8:	learn: 0.5767022	total: 8.36ms	remaining: 19.5ms
# 9:	learn: 0.5646789	total: 9.19ms	remaining: 18.4ms
# 10:	learn: 0.5543278	total: 10.1ms	remaining: 17.4ms
# 11:	learn: 0.5440353	total: 11ms	remaining: 16.4ms
# 12:	learn: 0.5367051	total: 11.8ms	remaining: 15.5ms
# 13:	learn: 0.5265848	total: 12.7ms	remaining: 14.5ms
# 14:	learn: 0.5179687	total: 13.7ms	remaining: 13.7ms
# 15:	learn: 0.5079571	total: 14.6ms	remaining: 12.7ms
# 16:	learn: 0.4981799	total: 15.4ms	remaining: 11.8ms
# 17:	learn: 0.4908447	total: 16.3ms	remaining: 10.9ms
# 18:	learn: 0.4819705	total: 17.3ms	remaining: 10ms
# 19:	learn: 0.4718108	total: 18.2ms	remaining: 9.11ms
# 20:	learn: 0.4630325	total: 19.1ms	remaining: 8.2ms
# 21:	learn: 0.4523674	total: 20.2ms	remaining: 7.35ms
# 22:	learn: 0.4432750	total: 21.1ms	remaining: 6.43ms
# 23:	learn: 0.4353979	total: 22ms	remaining: 5.51ms
# 24:	learn: 0.4281971	total: 23ms	remaining: 4.59ms
# 25:	learn: 0.4224987	total: 23.8ms	remaining: 3.66ms
# 26:	learn: 0.4147439	total: 24.7ms	remaining: 2.75ms
# 27:	learn: 0.4093523	total: 25.6ms	remaining: 1.83ms
# 28:	learn: 0.4012640	total: 26.5ms	remaining: 914us
# 29:	learn: 0.3950513	total: 27.6ms	remaining: 0us
# 0:	learn: 0.6778078	total: 976us	remaining: 28.3ms
# 1:	learn: 0.6627604	total: 2ms	remaining: 28.1ms
# 2:	learn: 0.6484351	total: 2.91ms	remaining: 26.2ms
# 3:	learn: 0.6368865	total: 3.94ms	remaining: 25.6ms
# 4:	learn: 0.6248818	total: 5.01ms	remaining: 25ms
# 5:	learn: 0.6150147	total: 6.06ms	remaining: 24.2ms
# 6:	learn: 0.6010762	total: 6.93ms	remaining: 22.8ms
# 7:	learn: 0.5896090	total: 7.79ms	remaining: 21.4ms
# 8:	learn: 0.5777841	total: 8.59ms	remaining: 20ms
# 9:	learn: 0.5638656	total: 9.42ms	remaining: 18.8ms
# 10:	learn: 0.5534516	total: 10.3ms	remaining: 17.7ms
# 11:	learn: 0.5429282	total: 11.2ms	remaining: 16.8ms
# 12:	learn: 0.5350111	total: 12ms	remaining: 15.7ms
# 13:	learn: 0.5239118	total: 18.7ms	remaining: 21.4ms
# 14:	learn: 0.5154880	total: 19.8ms	remaining: 19.8ms
# 15:	learn: 0.5053771	total: 20.9ms	remaining: 18.3ms
# 16:	learn: 0.4959519	total: 21.9ms	remaining: 16.7ms
# 17:	learn: 0.4893427	total: 22.8ms	remaining: 15.2ms
# 18:	learn: 0.4811473	total: 23.6ms	remaining: 13.7ms
# 19:	learn: 0.4711512	total: 24.6ms	remaining: 12.3ms
# 20:	learn: 0.4624554	total: 25.7ms	remaining: 11ms
# 21:	learn: 0.4529122	total: 26.8ms	remaining: 9.73ms
# 22:	learn: 0.4436507	total: 27.8ms	remaining: 8.45ms
# 23:	learn: 0.4371434	total: 29.1ms	remaining: 7.28ms
# 24:	learn: 0.4290354	total: 30.2ms	remaining: 6.05ms
# 25:	learn: 0.4236363	total: 31.2ms	remaining: 4.79ms
# 26:	learn: 0.4153036	total: 32.2ms	remaining: 3.58ms
# 27:	learn: 0.4084387	total: 33.3ms	remaining: 2.38ms
# 28:	learn: 0.4009847	total: 34.3ms	remaining: 1.18ms
# 29:	learn: 0.3956827	total: 35.2ms	remaining: 0us
# 0:	learn: 0.5457695	total: 1.68ms	remaining: 48.6ms
# 1:	learn: 0.4478922	total: 3.1ms	remaining: 43.4ms
# 2:	learn: 0.3771367	total: 4.67ms	remaining: 42ms
# 3:	learn: 0.3218347	total: 6.14ms	remaining: 39.9ms
# 4:	learn: 0.2877547	total: 7.36ms	remaining: 36.8ms
# 5:	learn: 0.2535812	total: 8.42ms	remaining: 33.7ms
# 6:	learn: 0.2288949	total: 9.61ms	remaining: 31.6ms
# 7:	learn: 0.1997731	total: 10.8ms	remaining: 29.8ms
# 8:	learn: 0.1804101	total: 12.5ms	remaining: 29.1ms
# 9:	learn: 0.1633528	total: 14ms	remaining: 28.1ms
# 10:	learn: 0.1497136	total: 15.2ms	remaining: 26.3ms
# 11:	learn: 0.1398193	total: 16.4ms	remaining: 24.6ms
# 12:	learn: 0.1308400	total: 17.7ms	remaining: 23.2ms
# 13:	learn: 0.1218400	total: 20ms	remaining: 22.8ms
# 14:	learn: 0.1146997	total: 21.5ms	remaining: 21.5ms
# 15:	learn: 0.1077469	total: 22.8ms	remaining: 19.9ms
# 16:	learn: 0.1028746	total: 24.2ms	remaining: 18.5ms
# 17:	learn: 0.0981094	total: 25.5ms	remaining: 17ms
# 18:	learn: 0.0955161	total: 27ms	remaining: 15.7ms
# 19:	learn: 0.0894611	total: 28.5ms	remaining: 14.2ms
# 20:	learn: 0.0870453	total: 73ms	remaining: 31.3ms
# 21:	learn: 0.0822203	total: 74.1ms	remaining: 26.9ms
# 22:	learn: 0.0768754	total: 76.2ms	remaining: 23.2ms
# 23:	learn: 0.0744693	total: 77.2ms	remaining: 19.3ms
# 24:	learn: 0.0696221	total: 78.2ms	remaining: 15.6ms
# 25:	learn: 0.0678564	total: 79.2ms	remaining: 12.2ms
# 26:	learn: 0.0637253	total: 80.2ms	remaining: 8.91ms
# 27:	learn: 0.0622169	total: 81.2ms	remaining: 5.8ms
# 28:	learn: 0.0597442	total: 82.6ms	remaining: 2.85ms
# 29:	learn: 0.0573469	total: 84ms	remaining: 0us
# 0:	learn: 0.5437406	total: 1.24ms	remaining: 36ms
# 1:	learn: 0.4336787	total: 2.36ms	remaining: 33ms
# 2:	learn: 0.3616853	total: 3.43ms	remaining: 30.9ms
# 3:	learn: 0.3078164	total: 4.31ms	remaining: 28ms
# 4:	learn: 0.2664936	total: 5.49ms	remaining: 27.4ms
# 5:	learn: 0.2416380	total: 6.5ms	remaining: 26ms
# 6:	learn: 0.2156228	total: 7.35ms	remaining: 24.1ms
# 7:	learn: 0.1786792	total: 8.46ms	remaining: 23.3ms
# 8:	learn: 0.1546752	total: 9.49ms	remaining: 22.1ms
# 9:	learn: 0.1351225	total: 10.6ms	remaining: 21.1ms
# 10:	learn: 0.1232215	total: 11.5ms	remaining: 19.8ms
# 11:	learn: 0.1134795	total: 12.5ms	remaining: 18.7ms
# 12:	learn: 0.1033999	total: 13.5ms	remaining: 17.6ms
# 13:	learn: 0.0946145	total: 14.3ms	remaining: 16.4ms
# 14:	learn: 0.0865224	total: 15.2ms	remaining: 15.2ms
# 15:	learn: 0.0792378	total: 16.3ms	remaining: 14.3ms
# 16:	learn: 0.0741804	total: 17.3ms	remaining: 13.3ms
# 17:	learn: 0.0712448	total: 18.2ms	remaining: 12.1ms
# 18:	learn: 0.0684052	total: 19.1ms	remaining: 11.1ms
# 19:	learn: 0.0649813	total: 20ms	remaining: 10ms
# 20:	learn: 0.0602442	total: 21ms	remaining: 9.01ms
# 21:	learn: 0.0577321	total: 22ms	remaining: 7.98ms
# 22:	learn: 0.0548702	total: 22.8ms	remaining: 6.93ms
# 23:	learn: 0.0528031	total: 23.9ms	remaining: 5.97ms
# 24:	learn: 0.0512080	total: 24.7ms	remaining: 4.94ms
# 25:	learn: 0.0504841	total: 25.5ms	remaining: 3.92ms
# 26:	learn: 0.0483647	total: 26.3ms	remaining: 2.92ms
# 27:	learn: 0.0450851	total: 27.2ms	remaining: 1.94ms
# 28:	learn: 0.0443920	total: 28ms	remaining: 964us
# 29:	learn: 0.0424507	total: 28.8ms	remaining: 0us
# 0:	learn: 0.5580312	total: 972us	remaining: 28.2ms
# 1:	learn: 0.4621271	total: 1.78ms	remaining: 25ms
# 2:	learn: 0.3811151	total: 2.57ms	remaining: 23.1ms
# 3:	learn: 0.3327370	total: 3.37ms	remaining: 21.9ms
# 4:	learn: 0.2927892	total: 4.29ms	remaining: 21.4ms
# 5:	learn: 0.2666658	total: 5.12ms	remaining: 20.5ms
# 6:	learn: 0.2395942	total: 5.91ms	remaining: 19.4ms
# 7:	learn: 0.2135423	total: 6.71ms	remaining: 18.5ms
# 8:	learn: 0.1927616	total: 7.66ms	remaining: 17.9ms
# 9:	learn: 0.1751977	total: 8.58ms	remaining: 17.2ms
# 10:	learn: 0.1610799	total: 9.38ms	remaining: 16.2ms
# 11:	learn: 0.1504067	total: 10.2ms	remaining: 15.3ms
# 12:	learn: 0.1448452	total: 11ms	remaining: 14.4ms
# 13:	learn: 0.1301879	total: 11.8ms	remaining: 13.5ms
# 14:	learn: 0.1218961	total: 12.7ms	remaining: 12.7ms
# 15:	learn: 0.1154623	total: 13.6ms	remaining: 11.9ms
# 16:	learn: 0.1092071	total: 14.7ms	remaining: 11.2ms
# 17:	learn: 0.1058745	total: 15.7ms	remaining: 10.5ms
# 18:	learn: 0.1010241	total: 16.6ms	remaining: 9.61ms
# 19:	learn: 0.0962324	total: 17.5ms	remaining: 8.73ms
# 20:	learn: 0.0918837	total: 18.3ms	remaining: 7.86ms
# 21:	learn: 0.0892711	total: 19.3ms	remaining: 7.03ms
# 22:	learn: 0.0842300	total: 20.2ms	remaining: 6.14ms
# 23:	learn: 0.0811960	total: 21ms	remaining: 5.26ms
# 24:	learn: 0.0780484	total: 21.8ms	remaining: 4.37ms
# 25:	learn: 0.0738605	total: 22.9ms	remaining: 3.52ms
# 26:	learn: 0.0700333	total: 24ms	remaining: 2.67ms
# 27:	learn: 0.0676469	total: 25ms	remaining: 1.78ms
# 28:	learn: 0.0662035	total: 25.8ms	remaining: 888us
# 29:	learn: 0.0636704	total: 26.6ms	remaining: 0us
# 0:	learn: 0.5599820	total: 920us	remaining: 26.7ms
# 1:	learn: 0.4716514	total: 2.04ms	remaining: 28.6ms
# 2:	learn: 0.3954312	total: 3.03ms	remaining: 27.3ms
# 3:	learn: 0.3375062	total: 3.96ms	remaining: 25.7ms
# 4:	learn: 0.2944295	total: 4.81ms	remaining: 24.1ms
# 5:	learn: 0.2563186	total: 5.62ms	remaining: 22.5ms
# 6:	learn: 0.2330422	total: 6.46ms	remaining: 21.2ms
# 7:	learn: 0.2024420	total: 7.25ms	remaining: 19.9ms
# 8:	learn: 0.1805259	total: 8.04ms	remaining: 18.8ms
# 9:	learn: 0.1604311	total: 8.91ms	remaining: 17.8ms
# 10:	learn: 0.1489160	total: 9.88ms	remaining: 17.1ms
# 11:	learn: 0.1392753	total: 10.8ms	remaining: 16.1ms
# 12:	learn: 0.1309069	total: 11.6ms	remaining: 15.2ms
# 13:	learn: 0.1213191	total: 12.4ms	remaining: 14.2ms
# 14:	learn: 0.1144755	total: 13.3ms	remaining: 13.3ms
# 15:	learn: 0.1084094	total: 14.1ms	remaining: 12.4ms
# 16:	learn: 0.1026259	total: 14.9ms	remaining: 11.4ms
# 17:	learn: 0.0994152	total: 15.7ms	remaining: 10.5ms
# 18:	learn: 0.0933041	total: 16.8ms	remaining: 9.72ms
# 19:	learn: 0.0888714	total: 17.6ms	remaining: 8.82ms
# 20:	learn: 0.0838151	total: 18.5ms	remaining: 7.92ms
# 21:	learn: 0.0790202	total: 19.4ms	remaining: 7.07ms
# 22:	learn: 0.0749155	total: 20.2ms	remaining: 6.16ms
# 23:	learn: 0.0718806	total: 21ms	remaining: 5.26ms
# 24:	learn: 0.0668021	total: 21.9ms	remaining: 4.39ms
# 25:	learn: 0.0654364	total: 22.7ms	remaining: 3.5ms
# 26:	learn: 0.0620844	total: 23.5ms	remaining: 2.62ms
# 27:	learn: 0.0606526	total: 24.7ms	remaining: 1.76ms
# 28:	learn: 0.0588360	total: 25.7ms	remaining: 885us
# 29:	learn: 0.0576498	total: 26.5ms	remaining: 0us
# 0:	learn: 0.5534788	total: 1.01ms	remaining: 29.2ms
# 1:	learn: 0.4489472	total: 1.86ms	remaining: 26.1ms
# 2:	learn: 0.3610868	total: 2.67ms	remaining: 24ms
# 3:	learn: 0.3114602	total: 3.47ms	remaining: 22.6ms
# 4:	learn: 0.2769460	total: 4.46ms	remaining: 22.3ms
# 5:	learn: 0.2414529	total: 5.28ms	remaining: 21.1ms
# 6:	learn: 0.2154564	total: 6.07ms	remaining: 19.9ms
# 7:	learn: 0.1940405	total: 6.84ms	remaining: 18.8ms
# 8:	learn: 0.1777116	total: 7.62ms	remaining: 17.8ms
# 9:	learn: 0.1581096	total: 8.39ms	remaining: 16.8ms
# 10:	learn: 0.1492382	total: 9.14ms	remaining: 15.8ms
# 11:	learn: 0.1378204	total: 9.92ms	remaining: 14.9ms
# 12:	learn: 0.1248250	total: 10.7ms	remaining: 14ms
# 13:	learn: 0.1182738	total: 11.8ms	remaining: 13.4ms
# 14:	learn: 0.1125930	total: 12.8ms	remaining: 12.8ms
# 15:	learn: 0.1065082	total: 13.8ms	remaining: 12.1ms
# 16:	learn: 0.0992044	total: 14.7ms	remaining: 11.2ms
# 17:	learn: 0.0942343	total: 15.6ms	remaining: 10.4ms
# 18:	learn: 0.0887120	total: 16.4ms	remaining: 9.49ms
# 19:	learn: 0.0839834	total: 17.2ms	remaining: 8.62ms
# 20:	learn: 0.0808212	total: 18ms	remaining: 7.73ms
# 21:	learn: 0.0782951	total: 19.2ms	remaining: 6.97ms
# 22:	learn: 0.0738054	total: 20.1ms	remaining: 6.11ms
# 23:	learn: 0.0707892	total: 20.9ms	remaining: 5.23ms
# 24:	learn: 0.0680601	total: 21.8ms	remaining: 4.35ms
# 25:	learn: 0.0649139	total: 22.6ms	remaining: 3.47ms
# 26:	learn: 0.0601282	total: 23.3ms	remaining: 2.59ms
# 27:	learn: 0.0579408	total: 24.2ms	remaining: 1.73ms
# 28:	learn: 0.0558750	total: 25ms	remaining: 861us
# 29:	learn: 0.0535800	total: 26ms	remaining: 0us
# 0:	learn: 0.5457695	total: 923us	remaining: 26.8ms
# 1:	learn: 0.4416249	total: 1.74ms	remaining: 24.3ms
# 2:	learn: 0.3753284	total: 2.54ms	remaining: 22.8ms
# 3:	learn: 0.3213373	total: 3.31ms	remaining: 21.5ms
# 4:	learn: 0.2882130	total: 4.11ms	remaining: 20.6ms
# 5:	learn: 0.2559125	total: 4.9ms	remaining: 19.6ms
# 6:	learn: 0.2337387	total: 5.94ms	remaining: 19.5ms
# 7:	learn: 0.2054300	total: 6.81ms	remaining: 18.7ms
# 8:	learn: 0.1854042	total: 7.67ms	remaining: 17.9ms
# 9:	learn: 0.1671987	total: 8.47ms	remaining: 16.9ms
# 10:	learn: 0.1531910	total: 9.28ms	remaining: 16ms
# 11:	learn: 0.1374087	total: 10.4ms	remaining: 15.6ms
# 12:	learn: 0.1311170	total: 11.2ms	remaining: 14.7ms
# 13:	learn: 0.1218126	total: 12.1ms	remaining: 13.8ms
# 14:	learn: 0.1115348	total: 13ms	remaining: 13ms
# 15:	learn: 0.1051179	total: 14ms	remaining: 12.3ms
# 16:	learn: 0.1003881	total: 14.9ms	remaining: 11.4ms
# 17:	learn: 0.0959936	total: 15.8ms	remaining: 10.5ms
# 18:	learn: 0.0937270	total: 16.7ms	remaining: 9.67ms
# 19:	learn: 0.0880194	total: 17.7ms	remaining: 8.84ms
# 20:	learn: 0.0860977	total: 18.6ms	remaining: 7.95ms
# 21:	learn: 0.0840447	total: 19.4ms	remaining: 7.06ms
# 22:	learn: 0.0792581	total: 20.2ms	remaining: 6.15ms
# 23:	learn: 0.0740975	total: 21.3ms	remaining: 5.32ms
# 24:	learn: 0.0699585	total: 22.2ms	remaining: 4.43ms
# 25:	learn: 0.0686103	total: 23.1ms	remaining: 3.56ms
# 26:	learn: 0.0643209	total: 24.2ms	remaining: 2.69ms
# 27:	learn: 0.0616277	total: 25.1ms	remaining: 1.79ms
# 28:	learn: 0.0593789	total: 26.1ms	remaining: 898us
# 29:	learn: 0.0572516	total: 26.9ms	remaining: 0us
# 0:	learn: 0.5437406	total: 1.32ms	remaining: 38.4ms
# 1:	learn: 0.4359282	total: 2.16ms	remaining: 30.2ms
# 2:	learn: 0.3623579	total: 2.95ms	remaining: 26.5ms
# 3:	learn: 0.3106907	total: 3.77ms	remaining: 24.5ms
# 4:	learn: 0.2675028	total: 4.69ms	remaining: 23.5ms
# 5:	learn: 0.2382706	total: 5.67ms	remaining: 22.7ms
# 6:	learn: 0.2150235	total: 6.51ms	remaining: 21.4ms
# 7:	learn: 0.1786655	total: 7.32ms	remaining: 20.1ms
# 8:	learn: 0.1548375	total: 8.22ms	remaining: 19.2ms
# 9:	learn: 0.1349809	total: 9.13ms	remaining: 18.3ms
# 10:	learn: 0.1219014	total: 10ms	remaining: 17.3ms
# 11:	learn: 0.1136613	total: 11ms	remaining: 16.5ms
# 12:	learn: 0.1072460	total: 12.1ms	remaining: 15.8ms
# 13:	learn: 0.0970615	total: 12.9ms	remaining: 14.8ms
# 14:	learn: 0.0877717	total: 13.7ms	remaining: 13.7ms
# 15:	learn: 0.0824433	total: 14.5ms	remaining: 12.7ms
# 16:	learn: 0.0765532	total: 15.2ms	remaining: 11.7ms
# 17:	learn: 0.0737234	total: 16.3ms	remaining: 10.9ms
# 18:	learn: 0.0704123	total: 17.3ms	remaining: 10ms
# 19:	learn: 0.0668917	total: 18.2ms	remaining: 9.1ms
# 20:	learn: 0.0632931	total: 19ms	remaining: 8.15ms
# 21:	learn: 0.0592369	total: 19.8ms	remaining: 7.22ms
# 22:	learn: 0.0560876	total: 20.6ms	remaining: 6.28ms
# 23:	learn: 0.0528575	total: 21.6ms	remaining: 5.39ms
# 24:	learn: 0.0514253	total: 22.4ms	remaining: 4.47ms
# 25:	learn: 0.0505742	total: 23.3ms	remaining: 3.59ms
# 26:	learn: 0.0484613	total: 24.2ms	remaining: 2.69ms
# 27:	learn: 0.0454399	total: 25.2ms	remaining: 1.8ms
# 28:	learn: 0.0445038	total: 26ms	remaining: 895us
# 29:	learn: 0.0424534	total: 26.8ms	remaining: 0us
# 0:	learn: 0.5512652	total: 936us	remaining: 27.2ms
# 1:	learn: 0.4509436	total: 2.28ms	remaining: 31.9ms
# 2:	learn: 0.3753578	total: 3.25ms	remaining: 29.3ms
# 3:	learn: 0.3208611	total: 4.03ms	remaining: 26.2ms
# 4:	learn: 0.2842039	total: 4.86ms	remaining: 24.3ms
# 5:	learn: 0.2530607	total: 5.67ms	remaining: 22.7ms
# 6:	learn: 0.2307926	total: 6.78ms	remaining: 22.3ms
# 7:	learn: 0.2060182	total: 7.8ms	remaining: 21.4ms
# 8:	learn: 0.1890060	total: 8.74ms	remaining: 20.4ms
# 9:	learn: 0.1698093	total: 9.62ms	remaining: 19.2ms
# 10:	learn: 0.1583853	total: 10.5ms	remaining: 18.1ms
# 11:	learn: 0.1477285	total: 11.3ms	remaining: 16.9ms
# 12:	learn: 0.1421819	total: 12.7ms	remaining: 16.6ms
# 13:	learn: 0.1296523	total: 13.5ms	remaining: 15.5ms
# 14:	learn: 0.1218551	total: 14.3ms	remaining: 14.3ms
# 15:	learn: 0.1152303	total: 15.1ms	remaining: 13.2ms
# 16:	learn: 0.1083801	total: 16.3ms	remaining: 12.4ms
# 17:	learn: 0.1053458	total: 17.1ms	remaining: 11.4ms
# 18:	learn: 0.1003852	total: 17.9ms	remaining: 10.4ms
# 19:	learn: 0.0960015	total: 18.8ms	remaining: 9.38ms
# 20:	learn: 0.0903451	total: 19.7ms	remaining: 8.43ms
# 21:	learn: 0.0876563	total: 20.4ms	remaining: 7.43ms
# 22:	learn: 0.0839429	total: 21.2ms	remaining: 6.44ms
# 23:	learn: 0.0802263	total: 21.9ms	remaining: 5.47ms
# 24:	learn: 0.0765856	total: 22.6ms	remaining: 4.53ms
# 25:	learn: 0.0738556	total: 23.6ms	remaining: 3.63ms
# 26:	learn: 0.0696898	total: 24.4ms	remaining: 2.71ms
# 27:	learn: 0.0666678	total: 25.2ms	remaining: 1.8ms
# 28:	learn: 0.0649490	total: 26.1ms	remaining: 898us
# 29:	learn: 0.0630060	total: 26.9ms	remaining: 0us
# 0:	learn: 0.5423830	total: 938us	remaining: 27.2ms
# 1:	learn: 0.4552768	total: 1.75ms	remaining: 24.6ms
# 2:	learn: 0.3723296	total: 2.56ms	remaining: 23ms
# 3:	learn: 0.3088083	total: 3.7ms	remaining: 24.1ms
# 4:	learn: 0.2713621	total: 4.65ms	remaining: 23.3ms
# 5:	learn: 0.2363339	total: 5.48ms	remaining: 21.9ms
# 6:	learn: 0.2157974	total: 6.43ms	remaining: 21.1ms
# 7:	learn: 0.1888957	total: 7.22ms	remaining: 19.9ms
# 8:	learn: 0.1697819	total: 8.06ms	remaining: 18.8ms
# 9:	learn: 0.1517264	total: 8.84ms	remaining: 17.7ms
# 10:	learn: 0.1382942	total: 9.6ms	remaining: 16.6ms
# 11:	learn: 0.1278325	total: 10.5ms	remaining: 15.7ms
# 12:	learn: 0.1206406	total: 11.5ms	remaining: 15ms
# 13:	learn: 0.1142141	total: 12.3ms	remaining: 14.1ms
# 14:	learn: 0.1077729	total: 13.1ms	remaining: 13.1ms
# 15:	learn: 0.1038929	total: 14ms	remaining: 12.2ms
# 16:	learn: 0.0993026	total: 14.8ms	remaining: 11.3ms
# 17:	learn: 0.0961289	total: 15.6ms	remaining: 10.4ms
# 18:	learn: 0.0910380	total: 16.4ms	remaining: 9.49ms
# 19:	learn: 0.0877770	total: 17.2ms	remaining: 8.59ms
# 20:	learn: 0.0838927	total: 18ms	remaining: 7.72ms
# 21:	learn: 0.0775155	total: 19ms	remaining: 6.9ms
# 22:	learn: 0.0735437	total: 19.8ms	remaining: 6.02ms
# 23:	learn: 0.0706606	total: 20.6ms	remaining: 5.15ms
# 24:	learn: 0.0664806	total: 21.4ms	remaining: 4.28ms
# 25:	learn: 0.0654526	total: 22.2ms	remaining: 3.41ms
# 26:	learn: 0.0600216	total: 23.3ms	remaining: 2.59ms
# 27:	learn: 0.0578792	total: 24.1ms	remaining: 1.72ms
# 28:	learn: 0.0543408	total: 24.8ms	remaining: 856us
# 29:	learn: 0.0523448	total: 25.7ms	remaining: 0us
# 0:	learn: 0.5534788	total: 1.28ms	remaining: 37.1ms
# 1:	learn: 0.4489472	total: 2.24ms	remaining: 31.4ms
# 2:	learn: 0.3610868	total: 3.15ms	remaining: 28.3ms
# 3:	learn: 0.3114602	total: 4.08ms	remaining: 26.5ms
# 4:	learn: 0.2769460	total: 4.96ms	remaining: 24.8ms
# 5:	learn: 0.2496724	total: 6.37ms	remaining: 25.5ms
# 6:	learn: 0.2223724	total: 7.31ms	remaining: 24ms
# 7:	learn: 0.1979922	total: 8.13ms	remaining: 22.4ms
# 8:	learn: 0.1754137	total: 9.02ms	remaining: 21.1ms
# 9:	learn: 0.1562992	total: 9.84ms	remaining: 19.7ms
# 10:	learn: 0.1472979	total: 10.6ms	remaining: 18.3ms
# 11:	learn: 0.1364136	total: 11.3ms	remaining: 17ms
# 12:	learn: 0.1271603	total: 12.1ms	remaining: 15.8ms
# 13:	learn: 0.1187777	total: 13ms	remaining: 14.8ms
# 14:	learn: 0.1134392	total: 13.8ms	remaining: 13.8ms
# 15:	learn: 0.1076979	total: 14.6ms	remaining: 12.8ms
# 16:	learn: 0.1002169	total: 15.4ms	remaining: 11.8ms
# 17:	learn: 0.0979235	total: 16.2ms	remaining: 10.8ms
# 18:	learn: 0.0921601	total: 17.3ms	remaining: 10ms
# 19:	learn: 0.0883825	total: 18.1ms	remaining: 9.06ms
# 20:	learn: 0.0850540	total: 19.1ms	remaining: 8.19ms
# 21:	learn: 0.0810525	total: 20ms	remaining: 7.26ms
# 22:	learn: 0.0768533	total: 21ms	remaining: 6.38ms
# 23:	learn: 0.0746430	total: 21.8ms	remaining: 5.44ms
# 24:	learn: 0.0715162	total: 22.6ms	remaining: 4.51ms
# 25:	learn: 0.0686411	total: 23.4ms	remaining: 3.6ms
# 26:	learn: 0.0636385	total: 24.5ms	remaining: 2.72ms
# 27:	learn: 0.0614546	total: 25.3ms	remaining: 1.81ms
# 28:	learn: 0.0595163	total: 26.1ms	remaining: 899us
# 29:	learn: 0.0568622	total: 27ms	remaining: 0us
# 0:	learn: 0.6780385	total: 997us	remaining: 28.9ms
# 1:	learn: 0.6645371	total: 1.78ms	remaining: 25ms
# 2:	learn: 0.6495888	total: 2.55ms	remaining: 23ms
# 3:	learn: 0.6377581	total: 3.38ms	remaining: 21.9ms
# 4:	learn: 0.6265180	total: 4.27ms	remaining: 21.3ms
# 5:	learn: 0.6140602	total: 5.19ms	remaining: 20.8ms
# 6:	learn: 0.6006807	total: 5.95ms	remaining: 19.6ms
# 7:	learn: 0.5897229	total: 6.7ms	remaining: 18.4ms
# 8:	learn: 0.5784181	total: 7.86ms	remaining: 18.3ms
# 9:	learn: 0.5671555	total: 8.7ms	remaining: 17.4ms
# 10:	learn: 0.5576235	total: 9.6ms	remaining: 16.6ms
# 11:	learn: 0.5485124	total: 10.4ms	remaining: 15.6ms
# 12:	learn: 0.5397459	total: 11.3ms	remaining: 14.7ms
# 13:	learn: 0.5302151	total: 12.1ms	remaining: 13.8ms
# 14:	learn: 0.5187924	total: 12.9ms	remaining: 12.9ms
# 15:	learn: 0.5096205	total: 13.7ms	remaining: 12ms
# 16:	learn: 0.5004985	total: 14.7ms	remaining: 11.3ms
# 17:	learn: 0.4925048	total: 15.7ms	remaining: 10.5ms
# 18:	learn: 0.4823881	total: 16.5ms	remaining: 9.54ms
# 19:	learn: 0.4737769	total: 17.3ms	remaining: 8.63ms
# 20:	learn: 0.4660949	total: 18.1ms	remaining: 7.74ms
# 21:	learn: 0.4573311	total: 18.9ms	remaining: 6.86ms
# 22:	learn: 0.4489674	total: 19.8ms	remaining: 6.03ms
# 23:	learn: 0.4426091	total: 20.6ms	remaining: 5.16ms
# 24:	learn: 0.4347245	total: 21.5ms	remaining: 4.3ms
# 25:	learn: 0.4280946	total: 22.3ms	remaining: 3.44ms
# 26:	learn: 0.4205340	total: 23.4ms	remaining: 2.6ms
# 27:	learn: 0.4155626	total: 24.3ms	remaining: 1.73ms
# 28:	learn: 0.4089746	total: 25.3ms	remaining: 871us
# 29:	learn: 0.4024762	total: 26.1ms	remaining: 0us
# 0:	learn: 0.6780170	total: 1.13ms	remaining: 32.6ms
# 1:	learn: 0.6628767	total: 1.93ms	remaining: 27ms
# 2:	learn: 0.6488293	total: 2.71ms	remaining: 24.4ms
# 3:	learn: 0.6365006	total: 3.46ms	remaining: 22.5ms
# 4:	learn: 0.6238297	total: 4.24ms	remaining: 21.2ms
# 5:	learn: 0.6140694	total: 5.04ms	remaining: 20.2ms
# 6:	learn: 0.6007306	total: 5.99ms	remaining: 19.7ms
# 7:	learn: 0.5885244	total: 6.78ms	remaining: 18.6ms
# 8:	learn: 0.5752545	total: 7.65ms	remaining: 17.8ms
# 9:	learn: 0.5602606	total: 8.6ms	remaining: 17.2ms
# 10:	learn: 0.5515233	total: 9.43ms	remaining: 16.3ms
# 11:	learn: 0.5427804	total: 10.2ms	remaining: 15.3ms
# 12:	learn: 0.5321555	total: 11ms	remaining: 14.4ms
# 13:	learn: 0.5215110	total: 11.8ms	remaining: 13.5ms
# 14:	learn: 0.5109647	total: 12.7ms	remaining: 12.7ms
# 15:	learn: 0.5012895	total: 13.5ms	remaining: 11.9ms
# 16:	learn: 0.4931045	total: 14.3ms	remaining: 11ms
# 17:	learn: 0.4853484	total: 15.3ms	remaining: 10.2ms
# 18:	learn: 0.4763067	total: 16.2ms	remaining: 9.35ms
# 19:	learn: 0.4657294	total: 17ms	remaining: 8.49ms
# 20:	learn: 0.4570551	total: 17.8ms	remaining: 7.62ms
# 21:	learn: 0.4473087	total: 18.6ms	remaining: 6.76ms
# 22:	learn: 0.4385062	total: 19.4ms	remaining: 5.89ms
# 23:	learn: 0.4307230	total: 20.1ms	remaining: 5.03ms
# 24:	learn: 0.4247830	total: 20.9ms	remaining: 4.18ms
# 25:	learn: 0.4187609	total: 21.7ms	remaining: 3.33ms
# 26:	learn: 0.4106928	total: 22.5ms	remaining: 2.5ms
# 27:	learn: 0.4053104	total: 23.5ms	remaining: 1.68ms
# 28:	learn: 0.3977612	total: 24.4ms	remaining: 841us
# 29:	learn: 0.3924217	total: 25.4ms	remaining: 0us
# 0:	learn: 0.6791102	total: 935us	remaining: 27.1ms
# 1:	learn: 0.6649687	total: 1.74ms	remaining: 24.4ms
# 2:	learn: 0.6534557	total: 2.54ms	remaining: 22.8ms
# 3:	learn: 0.6420895	total: 3.45ms	remaining: 22.4ms
# 4:	learn: 0.6306276	total: 4.36ms	remaining: 21.8ms
# 5:	learn: 0.6207221	total: 5.27ms	remaining: 21.1ms
# 6:	learn: 0.6082199	total: 6.1ms	remaining: 20.1ms
# 7:	learn: 0.5971304	total: 6.89ms	remaining: 18.9ms
# 8:	learn: 0.5855456	total: 7.69ms	remaining: 17.9ms
# 9:	learn: 0.5736352	total: 8.46ms	remaining: 16.9ms
# 10:	learn: 0.5634202	total: 9.3ms	remaining: 16.1ms
# 11:	learn: 0.5549049	total: 10.1ms	remaining: 15.1ms
# 12:	learn: 0.5444377	total: 11.3ms	remaining: 14.7ms
# 13:	learn: 0.5344918	total: 12.1ms	remaining: 13.8ms
# 14:	learn: 0.5250051	total: 12.9ms	remaining: 12.9ms
# 15:	learn: 0.5148701	total: 13.7ms	remaining: 12ms
# 16:	learn: 0.5043970	total: 14.5ms	remaining: 11.1ms
# 17:	learn: 0.4973863	total: 15.3ms	remaining: 10.2ms
# 18:	learn: 0.4878958	total: 16.1ms	remaining: 9.33ms
# 19:	learn: 0.4785984	total: 16.9ms	remaining: 8.45ms
# 20:	learn: 0.4695364	total: 17.8ms	remaining: 7.61ms
# 21:	learn: 0.4609526	total: 18.8ms	remaining: 6.82ms
# 22:	learn: 0.4516324	total: 19.6ms	remaining: 5.98ms
# 23:	learn: 0.4446800	total: 20.4ms	remaining: 5.11ms
# 24:	learn: 0.4383405	total: 21.2ms	remaining: 4.24ms
# 25:	learn: 0.4306874	total: 22ms	remaining: 3.39ms
# 26:	learn: 0.4224462	total: 22.9ms	remaining: 2.54ms
# 27:	learn: 0.4168544	total: 23.7ms	remaining: 1.69ms
# 28:	learn: 0.4096664	total: 24.4ms	remaining: 841us
# 29:	learn: 0.4035603	total: 25.2ms	remaining: 0us
# 0:	learn: 0.6790519	total: 963us	remaining: 27.9ms
# 1:	learn: 0.6669183	total: 1.75ms	remaining: 24.5ms
# 2:	learn: 0.6556261	total: 2.52ms	remaining: 22.7ms
# 3:	learn: 0.6439532	total: 3.31ms	remaining: 21.5ms
# 4:	learn: 0.6327240	total: 4.13ms	remaining: 20.6ms
# 5:	learn: 0.6222888	total: 4.9ms	remaining: 19.6ms
# 6:	learn: 0.6099887	total: 5.68ms	remaining: 18.7ms
# 7:	learn: 0.5987559	total: 6.42ms	remaining: 17.7ms
# 8:	learn: 0.5884477	total: 7.46ms	remaining: 17.4ms
# 9:	learn: 0.5768264	total: 8.28ms	remaining: 16.6ms
# 10:	learn: 0.5666050	total: 9.11ms	remaining: 15.7ms
# 11:	learn: 0.5567182	total: 9.94ms	remaining: 14.9ms
# 12:	learn: 0.5464934	total: 10.7ms	remaining: 14ms
# 13:	learn: 0.5366478	total: 11.5ms	remaining: 13.2ms
# 14:	learn: 0.5283885	total: 12.3ms	remaining: 12.3ms
# 15:	learn: 0.5187226	total: 13.1ms	remaining: 11.5ms
# 16:	learn: 0.5091618	total: 13.9ms	remaining: 10.6ms
# 17:	learn: 0.5021084	total: 15ms	remaining: 9.99ms
# 18:	learn: 0.4931131	total: 15.8ms	remaining: 9.16ms
# 19:	learn: 0.4833209	total: 16.8ms	remaining: 8.38ms
# 20:	learn: 0.4748284	total: 17.6ms	remaining: 7.55ms
# 21:	learn: 0.4643670	total: 18.4ms	remaining: 6.7ms
# 22:	learn: 0.4557191	total: 19.2ms	remaining: 5.85ms
# 23:	learn: 0.4476289	total: 20ms	remaining: 5ms
# 24:	learn: 0.4404132	total: 20.8ms	remaining: 4.17ms
# 25:	learn: 0.4345734	total: 21.7ms	remaining: 3.34ms
# 26:	learn: 0.4270973	total: 22.7ms	remaining: 2.52ms
# 27:	learn: 0.4216938	total: 23.6ms	remaining: 1.68ms
# 28:	learn: 0.4139772	total: 24.5ms	remaining: 844us
# 29:	learn: 0.4079392	total: 25.3ms	remaining: 0us
# 0:	learn: 0.6808750	total: 917us	remaining: 26.6ms
# 1:	learn: 0.6667501	total: 1.72ms	remaining: 24.1ms
# 2:	learn: 0.6530890	total: 2.77ms	remaining: 24.9ms
# 3:	learn: 0.6418268	total: 3.63ms	remaining: 23.6ms
# 4:	learn: 0.6303922	total: 4.44ms	remaining: 22.2ms
# 5:	learn: 0.6181268	total: 5.42ms	remaining: 21.7ms
# 6:	learn: 0.6046637	total: 6.25ms	remaining: 20.5ms
# 7:	learn: 0.5936777	total: 7.05ms	remaining: 19.4ms
# 8:	learn: 0.5838331	total: 7.88ms	remaining: 18.4ms
# 9:	learn: 0.5708029	total: 8.65ms	remaining: 17.3ms
# 10:	learn: 0.5607698	total: 9.52ms	remaining: 16.4ms
# 11:	learn: 0.5508978	total: 10.6ms	remaining: 15.9ms
# 12:	learn: 0.5432224	total: 11.5ms	remaining: 15ms
# 13:	learn: 0.5324159	total: 12.3ms	remaining: 14ms
# 14:	learn: 0.5246946	total: 13.1ms	remaining: 13.1ms
# 15:	learn: 0.5148785	total: 14ms	remaining: 12.2ms
# 16:	learn: 0.5057119	total: 14.8ms	remaining: 11.3ms
# 17:	learn: 0.4992037	total: 15.5ms	remaining: 10.4ms
# 18:	learn: 0.4918517	total: 16.3ms	remaining: 9.43ms
# 19:	learn: 0.4818779	total: 17.1ms	remaining: 8.55ms
# 20:	learn: 0.4729997	total: 18ms	remaining: 7.72ms
# 21:	learn: 0.4636634	total: 18.8ms	remaining: 6.84ms
# 22:	learn: 0.4551566	total: 19.6ms	remaining: 5.98ms
# 23:	learn: 0.4472282	total: 20.5ms	remaining: 5.13ms
# 24:	learn: 0.4392286	total: 21.4ms	remaining: 4.27ms
# 25:	learn: 0.4334781	total: 22.4ms	remaining: 3.45ms
# 26:	learn: 0.4252718	total: 23.2ms	remaining: 2.58ms
# 27:	learn: 0.4186062	total: 24ms	remaining: 1.71ms
# 28:	learn: 0.4113556	total: 24.8ms	remaining: 856us
# 29:	learn: 0.4060248	total: 25.8ms	remaining: 0us
# 0:	learn: 0.6780385	total: 1.14ms	remaining: 33.1ms
# 1:	learn: 0.6637776	total: 1.99ms	remaining: 27.8ms
# 2:	learn: 0.6488634	total: 2.78ms	remaining: 25ms
# 3:	learn: 0.6370410	total: 3.54ms	remaining: 23ms
# 4:	learn: 0.6258298	total: 4.57ms	remaining: 22.9ms
# 5:	learn: 0.6151675	total: 5.65ms	remaining: 22.6ms
# 6:	learn: 0.6017578	total: 6.9ms	remaining: 22.7ms
# 7:	learn: 0.5907858	total: 7.9ms	remaining: 21.7ms
# 8:	learn: 0.5794645	total: 8.77ms	remaining: 20.5ms
# 9:	learn: 0.5681730	total: 9.6ms	remaining: 19.2ms
# 10:	learn: 0.5584162	total: 10.4ms	remaining: 17.9ms
# 11:	learn: 0.5492877	total: 11.2ms	remaining: 16.7ms
# 12:	learn: 0.5423234	total: 12.1ms	remaining: 15.8ms
# 13:	learn: 0.5327427	total: 13ms	remaining: 14.8ms
# 14:	learn: 0.5212476	total: 13.8ms	remaining: 13.8ms
# 15:	learn: 0.5120138	total: 14.7ms	remaining: 12.9ms
# 16:	learn: 0.5035641	total: 15.6ms	remaining: 11.9ms
# 17:	learn: 0.4958198	total: 16.4ms	remaining: 11ms
# 18:	learn: 0.4856050	total: 17.3ms	remaining: 10ms
# 19:	learn: 0.4769100	total: 18.1ms	remaining: 9.05ms
# 20:	learn: 0.4691515	total: 19ms	remaining: 8.12ms
# 21:	learn: 0.4602899	total: 19.9ms	remaining: 7.25ms
# 22:	learn: 0.4519024	total: 20.8ms	remaining: 6.32ms
# 23:	learn: 0.4454721	total: 21.6ms	remaining: 5.4ms
# 24:	learn: 0.4392667	total: 22.4ms	remaining: 4.48ms
# 25:	learn: 0.4325345	total: 23.3ms	remaining: 3.59ms
# 26:	learn: 0.4242918	total: 24.2ms	remaining: 2.69ms
# 27:	learn: 0.4192472	total: 25ms	remaining: 1.78ms
# 28:	learn: 0.4125773	total: 25.7ms	remaining: 887us
# 29:	learn: 0.4059988	total: 26.6ms	remaining: 0us
# 0:	learn: 0.6780170	total: 936us	remaining: 27.2ms
# 1:	learn: 0.6628767	total: 1.75ms	remaining: 24.5ms
# 2:	learn: 0.6495273	total: 2.54ms	remaining: 22.8ms
# 3:	learn: 0.6376960	total: 3.61ms	remaining: 23.4ms
# 4:	learn: 0.6249989	total: 4.38ms	remaining: 21.9ms
# 5:	learn: 0.6152217	total: 5.15ms	remaining: 20.6ms
# 6:	learn: 0.6020705	total: 6.12ms	remaining: 20.1ms
# 7:	learn: 0.5898362	total: 7ms	remaining: 19.3ms
# 8:	learn: 0.5755612	total: 7.86ms	remaining: 18.3ms
# 9:	learn: 0.5605468	total: 8.86ms	remaining: 17.7ms
# 10:	learn: 0.5510202	total: 9.7ms	remaining: 16.8ms
# 11:	learn: 0.5422557	total: 10.5ms	remaining: 15.8ms
# 12:	learn: 0.5346194	total: 11.3ms	remaining: 14.8ms
# 13:	learn: 0.5245959	total: 12.1ms	remaining: 13.8ms
# 14:	learn: 0.5139417	total: 12.9ms	remaining: 12.9ms
# 15:	learn: 0.5053540	total: 13.9ms	remaining: 12.2ms
# 16:	learn: 0.4960996	total: 14.7ms	remaining: 11.3ms
# 17:	learn: 0.4882907	total: 15.6ms	remaining: 10.4ms
# 18:	learn: 0.4790613	total: 16.5ms	remaining: 9.54ms
# 19:	learn: 0.4682941	total: 17.4ms	remaining: 8.69ms
# 20:	learn: 0.4586393	total: 18.3ms	remaining: 7.84ms
# 21:	learn: 0.4488157	total: 19.1ms	remaining: 6.96ms
# 22:	learn: 0.4400009	total: 19.9ms	remaining: 6.05ms
# 23:	learn: 0.4321903	total: 20.7ms	remaining: 5.18ms
# 24:	learn: 0.4253731	total: 21.6ms	remaining: 4.33ms
# 25:	learn: 0.4193124	total: 22.4ms	remaining: 3.45ms
# 26:	learn: 0.4112000	total: 23.2ms	remaining: 2.58ms
# 27:	learn: 0.4057874	total: 24.3ms	remaining: 1.74ms
# 28:	learn: 0.3984530	total: 25.1ms	remaining: 865us
# 29:	learn: 0.3930889	total: 26.1ms	remaining: 0us
# 0:	learn: 0.6786268	total: 1.05ms	remaining: 30.5ms
# 1:	learn: 0.6637839	total: 1.9ms	remaining: 26.7ms
# 2:	learn: 0.6522889	total: 2.72ms	remaining: 24.4ms
# 3:	learn: 0.6409369	total: 3.51ms	remaining: 22.8ms
# 4:	learn: 0.6294873	total: 4.31ms	remaining: 21.5ms
# 5:	learn: 0.6195895	total: 5.24ms	remaining: 21ms
# 6:	learn: 0.6070934	total: 6ms	remaining: 19.7ms
# 7:	learn: 0.5960159	total: 6.82ms	remaining: 18.7ms
# 8:	learn: 0.5835030	total: 7.68ms	remaining: 17.9ms
# 9:	learn: 0.5716448	total: 8.47ms	remaining: 16.9ms
# 10:	learn: 0.5621797	total: 9.25ms	remaining: 16ms
# 11:	learn: 0.5537064	total: 10.1ms	remaining: 15.2ms
# 12:	learn: 0.5432638	total: 11ms	remaining: 14.4ms
# 13:	learn: 0.5333374	total: 12.2ms	remaining: 13.9ms
# 14:	learn: 0.5238967	total: 12.9ms	remaining: 12.9ms
# 15:	learn: 0.5137805	total: 13.7ms	remaining: 12ms
# 16:	learn: 0.5033264	total: 14.6ms	remaining: 11.2ms
# 17:	learn: 0.4963283	total: 15.5ms	remaining: 10.4ms
# 18:	learn: 0.4868556	total: 16.4ms	remaining: 9.49ms
# 19:	learn: 0.4775914	total: 17.2ms	remaining: 8.58ms
# 20:	learn: 0.4685480	total: 18ms	remaining: 7.71ms
# 21:	learn: 0.4595893	total: 18.8ms	remaining: 6.83ms
# 22:	learn: 0.4502954	total: 19.6ms	remaining: 5.97ms
# 23:	learn: 0.4432371	total: 20.4ms	remaining: 5.11ms
# 24:	learn: 0.4365843	total: 21.2ms	remaining: 4.24ms
# 25:	learn: 0.4289709	total: 22ms	remaining: 3.39ms
# 26:	learn: 0.4207853	total: 22.9ms	remaining: 2.54ms
# 27:	learn: 0.4152166	total: 23.9ms	remaining: 1.7ms
# 28:	learn: 0.4080717	total: 25ms	remaining: 860us
# 29:	learn: 0.4020214	total: 25.8ms	remaining: 0us
# 0:	learn: 0.6775037	total: 896us	remaining: 26ms
# 1:	learn: 0.6653794	total: 1.7ms	remaining: 23.8ms
# 2:	learn: 0.6511843	total: 7.97ms	remaining: 71.8ms
# 3:	learn: 0.6396121	total: 8.91ms	remaining: 57.9ms
# 4:	learn: 0.6284834	total: 9.79ms	remaining: 48.9ms
# 5:	learn: 0.6181416	total: 10.8ms	remaining: 43.3ms
# 6:	learn: 0.6059268	total: 11.7ms	remaining: 38.4ms
# 7:	learn: 0.5947845	total: 12.5ms	remaining: 34.4ms
# 8:	learn: 0.5826276	total: 13.3ms	remaining: 31.1ms
# 9:	learn: 0.5711369	total: 14.2ms	remaining: 28.4ms
# 10:	learn: 0.5610378	total: 15.1ms	remaining: 26.2ms
# 11:	learn: 0.5512771	total: 16.1ms	remaining: 24.1ms
# 12:	learn: 0.5441826	total: 17ms	remaining: 22.2ms
# 13:	learn: 0.5343947	total: 17.9ms	remaining: 20.5ms
# 14:	learn: 0.5261691	total: 18.9ms	remaining: 18.9ms
# 15:	learn: 0.5165362	total: 19.7ms	remaining: 17.3ms
# 16:	learn: 0.5070165	total: 20.6ms	remaining: 15.8ms
# 17:	learn: 0.5000027	total: 21.4ms	remaining: 14.3ms
# 18:	learn: 0.4910546	total: 22.3ms	remaining: 12.9ms
# 19:	learn: 0.4813238	total: 23.2ms	remaining: 11.6ms
# 20:	learn: 0.4728748	total: 24ms	remaining: 10.3ms
# 21:	learn: 0.4624653	total: 24.9ms	remaining: 9.04ms
# 22:	learn: 0.4536077	total: 26.1ms	remaining: 7.93ms
# 23:	learn: 0.4461096	total: 26.9ms	remaining: 6.72ms
# 24:	learn: 0.4389193	total: 27.7ms	remaining: 5.54ms
# 25:	learn: 0.4331728	total: 28.5ms	remaining: 4.39ms
# 26:	learn: 0.4239817	total: 29.3ms	remaining: 3.26ms
# 27:	learn: 0.4186308	total: 30.1ms	remaining: 2.15ms
# 28:	learn: 0.4109887	total: 31.1ms	remaining: 1.07ms
# 29:	learn: 0.4050179	total: 31.9ms	remaining: 0us
# 0:	learn: 0.6785058	total: 929us	remaining: 26.9ms
# 1:	learn: 0.6644364	total: 1.75ms	remaining: 24.5ms
# 2:	learn: 0.6508375	total: 2.55ms	remaining: 22.9ms
# 3:	learn: 0.6396331	total: 3.62ms	remaining: 23.5ms
# 4:	learn: 0.6282409	total: 4.58ms	remaining: 22.9ms
# 5:	learn: 0.6185900	total: 5.58ms	remaining: 22.3ms
# 6:	learn: 0.6052620	total: 6.58ms	remaining: 21.6ms
# 7:	learn: 0.5942717	total: 7.35ms	remaining: 20.2ms
# 8:	learn: 0.5818240	total: 8.16ms	remaining: 19ms
# 9:	learn: 0.5688467	total: 8.98ms	remaining: 18ms
# 10:	learn: 0.5585927	total: 10.2ms	remaining: 17.5ms
# 11:	learn: 0.5482746	total: 10.9ms	remaining: 16.4ms
# 12:	learn: 0.5406419	total: 11.7ms	remaining: 15.4ms
# 13:	learn: 0.5299239	total: 12.6ms	remaining: 14.4ms
# 14:	learn: 0.5217126	total: 13.7ms	remaining: 13.7ms
# 15:	learn: 0.5119999	total: 14.6ms	remaining: 12.8ms
# 16:	learn: 0.5029149	total: 15.4ms	remaining: 11.7ms
# 17:	learn: 0.4959868	total: 16.1ms	remaining: 10.8ms
# 18:	learn: 0.4877692	total: 17ms	remaining: 9.84ms
# 19:	learn: 0.4782711	total: 17.8ms	remaining: 8.9ms
# 20:	learn: 0.4699671	total: 18.7ms	remaining: 8.02ms
# 21:	learn: 0.4607505	total: 19.5ms	remaining: 7.1ms
# 22:	learn: 0.4520166	total: 20.3ms	remaining: 6.19ms
# 23:	learn: 0.4458226	total: 21.4ms	remaining: 5.34ms
# 24:	learn: 0.4378955	total: 22.3ms	remaining: 4.47ms
# 25:	learn: 0.4325428	total: 23.2ms	remaining: 3.56ms
# 26:	learn: 0.4243939	total: 24ms	remaining: 2.67ms
# 27:	learn: 0.4177912	total: 25ms	remaining: 1.78ms
# 28:	learn: 0.4105784	total: 25.8ms	remaining: 889us
# 29:	learn: 0.4052816	total: 26.6ms	remaining: 0us
# 0:	learn: 0.5559490	total: 1.11ms	remaining: 32.3ms
# 1:	learn: 0.4570717	total: 1.94ms	remaining: 27.2ms
# 2:	learn: 0.3888007	total: 2.73ms	remaining: 24.6ms
# 3:	learn: 0.3343621	total: 3.56ms	remaining: 23.1ms
# 4:	learn: 0.3007174	total: 4.32ms	remaining: 21.6ms
# 5:	learn: 0.2671148	total: 5.12ms	remaining: 20.5ms
# 6:	learn: 0.2451296	total: 5.89ms	remaining: 19.3ms
# 7:	learn: 0.2170467	total: 6.69ms	remaining: 18.4ms
# 8:	learn: 0.1963627	total: 7.46ms	remaining: 17.4ms
# 9:	learn: 0.1787760	total: 8.38ms	remaining: 16.8ms
# 10:	learn: 0.1693069	total: 9.2ms	remaining: 15.9ms
# 11:	learn: 0.1593396	total: 9.97ms	remaining: 15ms
# 12:	learn: 0.1531333	total: 10.7ms	remaining: 14ms
# 13:	learn: 0.1427302	total: 11.5ms	remaining: 13.1ms
# 14:	learn: 0.1306385	total: 12.2ms	remaining: 12.2ms
# 15:	learn: 0.1226019	total: 13ms	remaining: 11.4ms
# 16:	learn: 0.1162664	total: 13.8ms	remaining: 10.5ms
# 17:	learn: 0.1111227	total: 14.5ms	remaining: 9.68ms
# 18:	learn: 0.1083241	total: 15.7ms	remaining: 9.07ms
# ...
# 2:	learn: 0.4152327	total: 8.05ms	remaining: 72.5ms
# 3:	learn: 0.3643095	total: 10.7ms	remaining: 69.8ms
# 4:	learn: 0.3252647	total: 14.7ms	remaining: 73.7ms
# 5:	learn: 0.2777947	total: 18.4ms	remaining: 73.6ms
# 6:	learn: 0.2523314	total: 21.1ms	remaining: 69.5ms
# 7:	learn: 0.2273249	total: 23.7ms	remaining: 65.1ms
# 8:	learn: 0.2008555	total: 26.6ms	remaining: 62ms
# 9:	learn: 0.1823317	total: 30.3ms	remaining: 60.6ms
# 10:	learn: 0.1675880	total: 33.2ms	remaining: 57.3ms
# 11:	learn: 0.1555795	total: 36.4ms	remaining: 54.6ms
# 12:	learn: 0.1441277	total: 39ms	remaining: 51ms
# 13:	learn: 0.1320684	total: 42ms	remaining: 48ms
# 14:	learn: 0.1207757	total: 45.2ms	remaining: 45.2ms
# 15:	learn: 0.1132285	total: 48.1ms	remaining: 42.1ms
# 16:	learn: 0.1071855	total: 51.4ms	remaining: 39.3ms
# 17:	learn: 0.0999320	total: 54.5ms	remaining: 36.4ms
# 18:	learn: 0.0954771	total: 57.8ms	remaining: 33.5ms
# 19:	learn: 0.0910814	total: 60.8ms	remaining: 30.4ms
# 20:	learn: 0.0855515	total: 63.7ms	remaining: 27.3ms
# 21:	learn: 0.0814058	total: 67.1ms	remaining: 24.4ms
# 22:	learn: 0.0780935	total: 69.8ms	remaining: 21.3ms
# 23:	learn: 0.0746788	total: 73.1ms	remaining: 18.3ms
# 24:	learn: 0.0714197	total: 76.8ms	remaining: 15.4ms
# 25:	learn: 0.0681388	total: 79.7ms	remaining: 12.3ms
# 26:	learn: 0.0660515	total: 83ms	remaining: 9.22ms
# 27:	learn: 0.0634246	total: 85.8ms	remaining: 6.13ms
# 28:	learn: 0.0601708	total: 88.4ms	remaining: 3.05ms
# 29:	learn: 0.0583265	total: 91.7ms	remaining: 0us
# 0:	learn: 0.5718035	total: 2.81ms	remaining: 81.5ms
# 1:	learn: 0.4788971	total: 6.15ms	remaining: 86.2ms
# 2:	learn: 0.4208118	total: 8.73ms	remaining: 78.6ms
# 3:	learn: 0.3738801	total: 12.5ms	remaining: 81.5ms
# 4:	learn: 0.3335743	total: 15.3ms	remaining: 76.5ms
# 5:	learn: 0.2916193	total: 18.3ms	remaining: 73.3ms
# 6:	learn: 0.2688685	total: 21.7ms	remaining: 71.3ms
# 7:	learn: 0.2418666	total: 24.5ms	remaining: 67.3ms
# 8:	learn: 0.2196795	total: 27.3ms	remaining: 63.6ms
# 9:	learn: 0.2014772	total: 30.5ms	remaining: 60.9ms
# 10:	learn: 0.1849232	total: 33.2ms	remaining: 57.3ms
# 11:	learn: 0.1690679	total: 35.7ms	remaining: 53.6ms
# 12:	learn: 0.1564920	total: 38.4ms	remaining: 50.2ms
# 13:	learn: 0.1449546	total: 41.6ms	remaining: 47.6ms
# 14:	learn: 0.1364269	total: 56.8ms	remaining: 56.8ms
# 15:	learn: 0.1282933	total: 60.1ms	remaining: 52.6ms
# 16:	learn: 0.1215979	total: 62ms	remaining: 47.4ms
# 17:	learn: 0.1147927	total: 64.6ms	remaining: 43ms
# 18:	learn: 0.1080783	total: 67.7ms	remaining: 39.2ms
# 19:	learn: 0.1008300	total: 70.7ms	remaining: 35.4ms
# 20:	learn: 0.0965300	total: 73.4ms	remaining: 31.5ms
# 21:	learn: 0.0913639	total: 76.2ms	remaining: 27.7ms
# 22:	learn: 0.0877424	total: 78.9ms	remaining: 24ms
# 23:	learn: 0.0838569	total: 81.5ms	remaining: 20.4ms
# 24:	learn: 0.0805193	total: 84.9ms	remaining: 17ms
# 25:	learn: 0.0758459	total: 87.9ms	remaining: 13.5ms
# 26:	learn: 0.0732680	total: 91.1ms	remaining: 10.1ms
# 27:	learn: 0.0701691	total: 93.8ms	remaining: 6.7ms
# 28:	learn: 0.0662955	total: 96.7ms	remaining: 3.33ms
# 29:	learn: 0.0638920	total: 101ms	remaining: 0us
# 0:	learn: 0.5586779	total: 2.76ms	remaining: 80ms
# 1:	learn: 0.4764281	total: 5.62ms	remaining: 78.7ms
# 2:	learn: 0.4193699	total: 8.78ms	remaining: 79ms
# 3:	learn: 0.3722658	total: 11.9ms	remaining: 77.4ms
# 4:	learn: 0.3290269	total: 14.6ms	remaining: 73.2ms
# 5:	learn: 0.2862799	total: 18.2ms	remaining: 72.6ms
# 6:	learn: 0.2606213	total: 21.7ms	remaining: 71.2ms
# 7:	learn: 0.2342251	total: 24.4ms	remaining: 67.2ms
# 8:	learn: 0.2119529	total: 27.5ms	remaining: 64.3ms
# 9:	learn: 0.1929907	total: 30.5ms	remaining: 60.9ms
# 10:	learn: 0.1794516	total: 33.3ms	remaining: 57.5ms
# 11:	learn: 0.1649835	total: 36.9ms	remaining: 55.4ms
# 12:	learn: 0.1536966	total: 39.5ms	remaining: 51.7ms
# 13:	learn: 0.1435322	total: 42.5ms	remaining: 48.6ms
# 14:	learn: 0.1346275	total: 45.3ms	remaining: 45.3ms
# 15:	learn: 0.1258933	total: 47.8ms	remaining: 41.8ms
# 16:	learn: 0.1202524	total: 51.3ms	remaining: 39.2ms
# 17:	learn: 0.1139113	total: 54.2ms	remaining: 36.1ms
# 18:	learn: 0.1075238	total: 57.6ms	remaining: 33.4ms
# 19:	learn: 0.1016112	total: 60.3ms	remaining: 30.1ms
# 20:	learn: 0.0972471	total: 62.8ms	remaining: 26.9ms
# 21:	learn: 0.0929011	total: 66ms	remaining: 24ms
# 22:	learn: 0.0899633	total: 69.1ms	remaining: 21ms
# 23:	learn: 0.0859117	total: 71.8ms	remaining: 17.9ms
# 24:	learn: 0.0819168	total: 75.5ms	remaining: 15.1ms
# 25:	learn: 0.0783707	total: 78.1ms	remaining: 12ms
# 26:	learn: 0.0748704	total: 81.2ms	remaining: 9.02ms
# 27:	learn: 0.0715018	total: 84.2ms	remaining: 6.01ms
# 28:	learn: 0.0690160	total: 86.8ms	remaining: 2.99ms
# 29:	learn: 0.0662642	total: 90.1ms	remaining: 0us
# 0:	learn: 0.5779132	total: 2.36ms	remaining: 68.5ms
# 1:	learn: 0.4973890	total: 5.71ms	remaining: 79.9ms
# 2:	learn: 0.4248751	total: 8.61ms	remaining: 77.5ms
# 3:	learn: 0.3654596	total: 11.1ms	remaining: 71.8ms
# 4:	learn: 0.3250385	total: 14ms	remaining: 70.2ms
# 5:	learn: 0.2880317	total: 17.3ms	remaining: 69ms
# 6:	learn: 0.2595163	total: 20.5ms	remaining: 67.2ms
# 7:	learn: 0.2334340	total: 23.2ms	remaining: 63.9ms
# 8:	learn: 0.2108407	total: 26.2ms	remaining: 61.2ms
# 9:	learn: 0.1941034	total: 29.3ms	remaining: 58.6ms
# 10:	learn: 0.1782179	total: 32.4ms	remaining: 56ms
# 11:	learn: 0.1628612	total: 35.4ms	remaining: 53ms
# 12:	learn: 0.1502696	total: 38.3ms	remaining: 50ms
# 13:	learn: 0.1416324	total: 40.9ms	remaining: 46.8ms
# 14:	learn: 0.1343481	total: 43.7ms	remaining: 43.7ms
# 15:	learn: 0.1268409	total: 47ms	remaining: 41.2ms
# 16:	learn: 0.1195372	total: 49.6ms	remaining: 37.9ms
# 17:	learn: 0.1120698	total: 53.3ms	remaining: 35.5ms
# 18:	learn: 0.1052021	total: 56.2ms	remaining: 32.5ms
# 19:	learn: 0.0975573	total: 59ms	remaining: 29.5ms
# 20:	learn: 0.0932174	total: 63.3ms	remaining: 27.1ms
# 21:	learn: 0.0880038	total: 66.2ms	remaining: 24.1ms
# 22:	learn: 0.0837111	total: 69.3ms	remaining: 21.1ms
# 23:	learn: 0.0800191	total: 72.1ms	remaining: 18ms
# 24:	learn: 0.0771027	total: 74.8ms	remaining: 15ms
# 25:	learn: 0.0730831	total: 78.1ms	remaining: 12ms
# 26:	learn: 0.0690690	total: 81.2ms	remaining: 9.02ms
# 27:	learn: 0.0667641	total: 84.6ms	remaining: 6.04ms
# 28:	learn: 0.0640244	total: 87.4ms	remaining: 3.01ms
# 29:	learn: 0.0605094	total: 90.5ms	remaining: 0us
# 0:	learn: 0.5689513	total: 2.46ms	remaining: 71.4ms
# 1:	learn: 0.4831439	total: 5.32ms	remaining: 74.4ms
# 2:	learn: 0.4229605	total: 8.35ms	remaining: 75.1ms
# 3:	learn: 0.3691084	total: 11.4ms	remaining: 74ms
# 4:	learn: 0.3308501	total: 14.9ms	remaining: 74.3ms
# 5:	learn: 0.2949852	total: 17.6ms	remaining: 70.2ms
# 6:	learn: 0.2677963	total: 20.7ms	remaining: 68.1ms
# 7:	learn: 0.2460953	total: 24.9ms	remaining: 68.6ms
# 8:	learn: 0.2225137	total: 28.4ms	remaining: 66.3ms
# 9:	learn: 0.2025537	total: 33.1ms	remaining: 66.2ms
# 10:	learn: 0.1849801	total: 36.6ms	remaining: 63.2ms
# 11:	learn: 0.1726707	total: 40.9ms	remaining: 61.4ms
# 12:	learn: 0.1629444	total: 44.3ms	remaining: 57.9ms
# 13:	learn: 0.1536013	total: 48.4ms	remaining: 55.3ms
# 14:	learn: 0.1443989	total: 52ms	remaining: 52ms
# 15:	learn: 0.1326699	total: 55.7ms	remaining: 48.8ms
# 16:	learn: 0.1253009	total: 59.3ms	remaining: 45.3ms
# 17:	learn: 0.1169328	total: 63.5ms	remaining: 42.3ms
# 18:	learn: 0.1098549	total: 67.1ms	remaining: 38.8ms
# 19:	learn: 0.1039927	total: 71ms	remaining: 35.5ms
# 20:	learn: 0.0992529	total: 75.1ms	remaining: 32.2ms
# 21:	learn: 0.0930650	total: 79.7ms	remaining: 29ms
# 22:	learn: 0.0902266	total: 93.1ms	remaining: 28.3ms
# 23:	learn: 0.0853852	total: 96.2ms	remaining: 24.1ms
# 24:	learn: 0.0813850	total: 99.3ms	remaining: 19.9ms
# 25:	learn: 0.0776784	total: 102ms	remaining: 15.7ms
# 26:	learn: 0.0737431	total: 105ms	remaining: 11.7ms
# 27:	learn: 0.0712129	total: 108ms	remaining: 7.72ms
# 28:	learn: 0.0676574	total: 111ms	remaining: 3.82ms
# 29:	learn: 0.0644322	total: 113ms	remaining: 0us
# 0:	learn: 0.5681285	total: 2.58ms	remaining: 74.9ms
# 1:	learn: 0.4782310	total: 5.61ms	remaining: 78.6ms
# 2:	learn: 0.4157604	total: 8.94ms	remaining: 80.5ms
# 3:	learn: 0.3657944	total: 12.4ms	remaining: 80.5ms
# 4:	learn: 0.3255580	total: 15.8ms	remaining: 79.2ms
# 5:	learn: 0.2779784	total: 19.3ms	remaining: 77.2ms
# 6:	learn: 0.2497788	total: 22ms	remaining: 72.2ms
# 7:	learn: 0.2244694	total: 26.2ms	remaining: 72.2ms
# 8:	learn: 0.1987378	total: 29.3ms	remaining: 68.3ms
# 9:	learn: 0.1804771	total: 33ms	remaining: 66ms
# 10:	learn: 0.1658400	total: 36.1ms	remaining: 62.3ms
# 11:	learn: 0.1538349	total: 38.9ms	remaining: 58.4ms
# 12:	learn: 0.1412456	total: 42.3ms	remaining: 55.3ms
# 13:	learn: 0.1294671	total: 45.2ms	remaining: 51.7ms
# 14:	learn: 0.1216609	total: 48.2ms	remaining: 48.2ms
# 15:	learn: 0.1135683	total: 50.9ms	remaining: 44.5ms
# 16:	learn: 0.1074276	total: 53.7ms	remaining: 41ms
# 17:	learn: 0.1017464	total: 57.3ms	remaining: 38.2ms
# 18:	learn: 0.0973005	total: 60.2ms	remaining: 34.9ms
# 19:	learn: 0.0928282	total: 63.5ms	remaining: 31.7ms
# 20:	learn: 0.0873319	total: 66.2ms	remaining: 28.4ms
# 21:	learn: 0.0836465	total: 68.7ms	remaining: 25ms
# 22:	learn: 0.0801329	total: 72ms	remaining: 21.9ms
# 23:	learn: 0.0768440	total: 75.1ms	remaining: 18.8ms
# 24:	learn: 0.0735103	total: 77.6ms	remaining: 15.5ms
# 25:	learn: 0.0689580	total: 81ms	remaining: 12.5ms
# 26:	learn: 0.0665357	total: 83.8ms	remaining: 9.31ms
# 27:	learn: 0.0634298	total: 86.7ms	remaining: 6.19ms
# 28:	learn: 0.0604863	total: 90ms	remaining: 3.1ms
# 29:	learn: 0.0578064	total: 92.9ms	remaining: 0us
# 0:	learn: 0.5629564	total: 2.58ms	remaining: 74.8ms
# 1:	learn: 0.4842503	total: 5.2ms	remaining: 72.9ms
# 2:	learn: 0.4250610	total: 8.51ms	remaining: 76.5ms
# 3:	learn: 0.3774098	total: 11.2ms	remaining: 72.8ms
# 4:	learn: 0.3369678	total: 13.8ms	remaining: 68.9ms
# 5:	learn: 0.2940662	total: 17ms	remaining: 68.1ms
# 6:	learn: 0.2704122	total: 20.1ms	remaining: 66.2ms
# 7:	learn: 0.2432813	total: 22.9ms	remaining: 62.9ms
# 8:	learn: 0.2205028	total: 26ms	remaining: 60.6ms
# 9:	learn: 0.2023289	total: 29.1ms	remaining: 58.2ms
# 10:	learn: 0.1851253	total: 32ms	remaining: 55.2ms
# 11:	learn: 0.1702736	total: 35ms	remaining: 52.5ms
# 12:	learn: 0.1575868	total: 38ms	remaining: 49.6ms
# 13:	learn: 0.1443389	total: 40.8ms	remaining: 46.6ms
# 14:	learn: 0.1359649	total: 43.3ms	remaining: 43.3ms
# 15:	learn: 0.1279792	total: 45.9ms	remaining: 40.1ms
# 16:	learn: 0.1212046	total: 49.3ms	remaining: 37.7ms
# 17:	learn: 0.1138693	total: 52.1ms	remaining: 34.7ms
# 18:	learn: 0.1088252	total: 55ms	remaining: 31.8ms
# 19:	learn: 0.1030657	total: 67.2ms	remaining: 33.6ms
# 20:	learn: 0.0991672	total: 69.8ms	remaining: 29.9ms
# 21:	learn: 0.0940153	total: 72.9ms	remaining: 26.5ms
# 22:	learn: 0.0916381	total: 75.9ms	remaining: 23.1ms
# 23:	learn: 0.0875939	total: 78.7ms	remaining: 19.7ms
# 24:	learn: 0.0836919	total: 81.4ms	remaining: 16.3ms
# 25:	learn: 0.0790274	total: 84.6ms	remaining: 13ms
# 26:	learn: 0.0760428	total: 87.5ms	remaining: 9.73ms
# 27:	learn: 0.0729854	total: 90.2ms	remaining: 6.44ms
# 28:	learn: 0.0697250	total: 92.6ms	remaining: 3.19ms
# 29:	learn: 0.0671870	total: 96.3ms	remaining: 0us
# 0:	learn: 0.5586779	total: 2.33ms	remaining: 67.7ms
# 1:	learn: 0.4764281	total: 5.86ms	remaining: 82.1ms
# 2:	learn: 0.4193699	total: 8.92ms	remaining: 80.3ms
# 3:	learn: 0.3638113	total: 12.5ms	remaining: 81.1ms
# 4:	learn: 0.3215749	total: 15.1ms	remaining: 75.4ms
# 5:	learn: 0.2804312	total: 17.9ms	remaining: 71.4ms
# 6:	learn: 0.2577892	total: 21.6ms	remaining: 70.8ms
# 7:	learn: 0.2355032	total: 24.3ms	remaining: 66.7ms
# 8:	learn: 0.2126383	total: 28ms	remaining: 65.4ms
# 9:	learn: 0.1935137	total: 31ms	remaining: 62ms
# 10:	learn: 0.1770499	total: 34.1ms	remaining: 59ms
# 11:	learn: 0.1637699	total: 37.5ms	remaining: 56.2ms
# 12:	learn: 0.1504829	total: 40.2ms	remaining: 52.5ms
# 13:	learn: 0.1402456	total: 43.5ms	remaining: 49.7ms
# 14:	learn: 0.1308584	total: 46.5ms	remaining: 46.5ms
# 15:	learn: 0.1222472	total: 49.4ms	remaining: 43.2ms
# 16:	learn: 0.1169947	total: 52.7ms	remaining: 40.3ms
# 17:	learn: 0.1110006	total: 56.2ms	remaining: 37.5ms
# 18:	learn: 0.1049299	total: 59.5ms	remaining: 34.5ms
# 19:	learn: 0.0995057	total: 78.1ms	remaining: 39.1ms
# 20:	learn: 0.0952846	total: 80.7ms	remaining: 34.6ms
# 21:	learn: 0.0911833	total: 83.5ms	remaining: 30.4ms
# 22:	learn: 0.0874066	total: 86.7ms	remaining: 26.4ms
# 23:	learn: 0.0836266	total: 89.4ms	remaining: 22.4ms
# 24:	learn: 0.0798231	total: 92.5ms	remaining: 18.5ms
# 25:	learn: 0.0751434	total: 95.6ms	remaining: 14.7ms
# 26:	learn: 0.0724557	total: 98.5ms	remaining: 10.9ms
# 27:	learn: 0.0692796	total: 102ms	remaining: 7.25ms
# 28:	learn: 0.0663348	total: 105ms	remaining: 3.61ms
# 29:	learn: 0.0637776	total: 108ms	remaining: 0us
# 0:	learn: 0.5749047	total: 19.6ms	remaining: 567ms
# 1:	learn: 0.4882950	total: 22.8ms	remaining: 319ms
# 2:	learn: 0.4173742	total: 25.6ms	remaining: 230ms
# 3:	learn: 0.3688167	total: 28.2ms	remaining: 183ms
# 4:	learn: 0.3305658	total: 32.3ms	remaining: 162ms
# 5:	learn: 0.2934149	total: 35.3ms	remaining: 141ms
# 6:	learn: 0.2635545	total: 38.4ms	remaining: 126ms
# 7:	learn: 0.2364793	total: 41.5ms	remaining: 114ms
# 8:	learn: 0.2093220	total: 44.1ms	remaining: 103ms
# 9:	learn: 0.1904807	total: 47.6ms	remaining: 95.2ms
# 10:	learn: 0.1750036	total: 50.9ms	remaining: 87.9ms
# 11:	learn: 0.1617937	total: 54ms	remaining: 81.1ms
# 12:	learn: 0.1479833	total: 56.7ms	remaining: 74.1ms
# 13:	learn: 0.1397310	total: 59.5ms	remaining: 68ms
# 14:	learn: 0.1312575	total: 62.7ms	remaining: 62.7ms
# 15:	learn: 0.1240494	total: 65.5ms	remaining: 57.3ms
# 16:	learn: 0.1161319	total: 69ms	remaining: 52.8ms
# 17:	learn: 0.1079678	total: 71.8ms	remaining: 47.9ms
# 18:	learn: 0.1024879	total: 74.3ms	remaining: 43ms
# 19:	learn: 0.0977667	total: 77.5ms	remaining: 38.8ms
# 20:	learn: 0.0932959	total: 80.8ms	remaining: 34.6ms
# 21:	learn: 0.0885312	total: 84.2ms	remaining: 30.6ms
# 22:	learn: 0.0848171	total: 87.3ms	remaining: 26.6ms
# 23:	learn: 0.0810200	total: 90ms	remaining: 22.5ms
# 24:	learn: 0.0775850	total: 92.8ms	remaining: 18.6ms
# 25:	learn: 0.0727897	total: 95.8ms	remaining: 14.7ms
# 26:	learn: 0.0688393	total: 98.4ms	remaining: 10.9ms
# 27:	learn: 0.0665612	total: 101ms	remaining: 7.23ms
# 28:	learn: 0.0641384	total: 104ms	remaining: 3.59ms
# 29:	learn: 0.0601099	total: 107ms	remaining: 0us
# 0:	learn: 0.5700901	total: 1.27ms	remaining: 36.7ms
# 1:	learn: 0.4685085	total: 2.44ms	remaining: 34.2ms
# 2:	learn: 0.3845410	total: 3.56ms	remaining: 32ms
# 3:	learn: 0.3320734	total: 4.89ms	remaining: 31.8ms
# 4:	learn: 0.2948256	total: 6.1ms	remaining: 30.5ms
# 5:	learn: 0.2535449	total: 7.21ms	remaining: 28.8ms
# 6:	learn: 0.2266481	total: 8.49ms	remaining: 27.9ms
# 7:	learn: 0.2020070	total: 9.77ms	remaining: 26.9ms
# 8:	learn: 0.1833691	total: 10.9ms	remaining: 25.5ms
# 9:	learn: 0.1669739	total: 12.3ms	remaining: 24.6ms
# 10:	learn: 0.1547140	total: 13.8ms	remaining: 23.8ms
# 11:	learn: 0.1449255	total: 15.7ms	remaining: 23.6ms
# 12:	learn: 0.1358713	total: 17ms	remaining: 22.2ms
# 13:	learn: 0.1252823	total: 18.6ms	remaining: 21.3ms
# 14:	learn: 0.1182425	total: 20.9ms	remaining: 20.9ms
# 15:	learn: 0.1106088	total: 22.5ms	remaining: 19.6ms
# 16:	learn: 0.1048874	total: 23.7ms	remaining: 18.1ms
# 17:	learn: 0.0980598	total: 25.2ms	remaining: 16.8ms
# 18:	learn: 0.0922674	total: 26.6ms	remaining: 15.4ms
# 19:	learn: 0.0876817	total: 28.3ms	remaining: 14.2ms
# 20:	learn: 0.0847996	total: 30ms	remaining: 12.9ms
# 21:	learn: 0.0811743	total: 31.4ms	remaining: 11.4ms
# 22:	learn: 0.0779057	total: 32.8ms	remaining: 9.97ms
# 23:	learn: 0.0738095	total: 34.1ms	remaining: 8.52ms
# 24:	learn: 0.0699717	total: 35.6ms	remaining: 7.13ms
# 25:	learn: 0.0662032	total: 37.5ms	remaining: 5.77ms
# 26:	learn: 0.0628765	total: 38.9ms	remaining: 4.32ms
# 27:	learn: 0.0609219	total: 40.2ms	remaining: 2.87ms
# 28:	learn: 0.0591065	total: 41.5ms	remaining: 1.43ms
# 29:	learn: 0.0571484	total: 42.8ms	remaining: 0us
# GridSearchCV(cv=5,
#              estimator=<catboost.core.CatBoostClassifier object at 0x0000021A3AA9CFA0>,
#              param_grid={'border_count': [32, 64],
#                          'colsample_bylevel': [0.8, 0.9],
#                          'custom_metric': ['AUC', 'Logloss'],
#                          'depth': [4, 6, 8], 'l2_leaf_reg': [3, 5, 7],
#                          'learning_rate': [0.01, 0.1],
#                          'subsample': [0.8, 0.9]})

# %%
best_params = grid_search.best_params_
print("Best params: ", best_params)
# Out:
# Best params:  {'border_count': 32, 'colsample_bylevel': 0.9, 'custom_metric': 'AUC', 'depth': 6, 'l2_leaf_reg': 7, 'learning_rate': 0.1, 'subsample': 0.8}

# %%
cat_best = grid_search.best_estimator_
y_pred_cat = cat_best.predict(x_teste)

# %%
acuracia = accuracy_score(y_teste,y_pred_cat)
precisao = precision_score(y_teste,y_pred_cat)
recall = recall_score(y_teste,y_pred_cat)
f1Score = f1_score(y_teste,y_pred_cat)
kappa = cohen_kappa_score(y_teste,y_pred_cat)

print('---------- CatBoost ---------\n')
print(f'Acurácia: {acuracia}')
print(f'Precisão: {precisao}')
print(f'Recall ou Sensibilidade: {recall}')
print(f'F1-Score: {f1Score}')
print(f'Kappa: {kappa}')
# Out:
# ---------- CatBoost ---------
#
# Acurácia: 0.9707602339181286
# Precisão: 0.963963963963964
# Recall ou Sensibilidade: 0.9907407407407407
# F1-Score: 0.9771689497716894
# Kappa: 0.9365397461589846

# %%
cat_fpG, cat_vpG, lim4G = roc_curve(y_teste, y_pred_cat)
cat_curva_rocG = roc_auc_score(y_teste,y_pred_cat)

plt.plot(cat_fpG, cat_vpG, marker=".", label="CatBoost "+str(round(gbm_curva_roc, 2)), color="yellow")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
cat_probsG = grid_search.predict_proba(x_teste)[:,1]

cat_fpG, cat_vpG, lim4G = roc_curve(y_teste, cat_probsG)

plt.plot(cat_fpG, cat_vpG, marker=".", label="CatBoost", color="yellow")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# # SVC

# %%
from sklearn.svm import SVC

# %%
svc = SVC(random_state=random_state, probability=True)

model = svc.fit(x_treino, y_treino)

svc_predict = model.predict(x_teste)

svc_predict_prob = svc.predict_proba(x_teste)

# %% [markdown]
# ## Gráficos

# %%
sns.heatmap(confusion_matrix(y_teste, svc_predict), cmap='OrRd', annot=True, fmt='2.0f')
plt.title('SVC')
plt.ylabel('PREVISTO')
plt.xlabel('REAL')
plt.show()

# %%
svc_fp, svc_vp, lim5 = roc_curve(y_teste, svc_predict)
svc_curva_roc = roc_auc_score(y_teste,svc_predict)

plt.plot(svc_fp, svc_vp, marker=".", label="SVC "+str(round(svc_curva_roc, 2)), color="brown")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
svc_probs = svc_predict_prob[:,1]

svc_fp, svc_vp, lim5 = roc_curve(y_teste, svc_probs)

plt.plot(svc_fp, svc_vp, marker=".", label="SVC", color="brown")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# ## Resultado

# %%
acuracia = accuracy_score(y_teste,svc_predict)
precisao = precision_score(y_teste,svc_predict)
recall = recall_score(y_teste,svc_predict)
f1Score = f1_score(y_teste,svc_predict)
svc_curva_rocG = roc_auc_score(y_teste,svc_predict)
kappa = cohen_kappa_score(y_teste,svc_predict)

print('------ CatBoost ---------\n')
print(f'Acurácia: {acuracia}')
print(f'Precisão: {precisao}')
print(f'Recall ou Sensibilidade: {recall}')
print(f'F1-Score: {f1Score}')
print(f'Kappa: {kappa}')
# Out:
# ------ CatBoost ---------
#
# Acurácia: 0.9824561403508771
# Precisão: 0.981651376146789
# Recall ou Sensibilidade: 0.9907407407407407
# F1-Score: 0.9861751152073732
# Kappa: 0.9621765096217652

# %% [markdown]
# ## GridSearchCV

# %%
parameters = {
    'C': [0.1, 1.0, 10.0],
    'kernel': ['linear', 'rbf', 'poly'],
    'degree': [2, 3],
    'gamma': ['scale', 'auto', 0.1, 1.0],
    'coef0': [0.0, 0.1],
    'shrinking': [True, False],
    'probability': [True, False],
    'class_weight': [None, 'balanced', {0: 1, 1: 2}]
}

# %%
grid_search = GridSearchCV(svc, parameters, cv=5)
grid_search.fit(x_treino, y_treino)
# Out:
# GridSearchCV(cv=5, estimator=SVC(probability=True, random_state=42),
#              param_grid={'C': [0.1, 1.0, 10.0],
#                          'class_weight': [None, 'balanced', {0: 1, 1: 2}],
#                          'coef0': [0.0, 0.1], 'degree': [2, 3],
#                          'gamma': ['scale', 'auto', 0.1, 1.0],
#                          'kernel': ['linear', 'rbf', 'poly'],
#                          'probability': [True, False],
#                          'shrinking': [True, False]})

# %%
best_params = grid_search.best_params_
print("Melhores parametros: ", best_params)
# Out:
# Melhores parametros:  {'C': 1.0, 'class_weight': None, 'coef0': 0.0, 'degree': 2, 'gamma': 1.0, 'kernel': 'poly', 'probability': True, 'shrinking': True}

# %%
svc_best = grid_search.best_estimator_
y_pred_svc = svc_best.predict(x_teste)

# %%
acuracia = accuracy_score(y_teste,y_pred_svc)
precisao = precision_score(y_teste,y_pred_svc)
recall = recall_score(y_teste,y_pred_svc)
f1Score = f1_score(y_teste,y_pred_svc)
kappa = cohen_kappa_score(y_teste,y_pred_svc)

print('--------- SVC ---------\n')
print(f'Acurácia: {acuracia}')
print(f'Precisão: {precisao}')
print(f'Recall ou Sensibilidade: {recall}')
print(f'F1-Score: {f1Score}')
print(f'Kappa: {kappa}')
# Out:
# --------- SVC ---------
#
# Acurácia: 0.9883040935672515
# Precisão: 0.9818181818181818
# Recall ou Sensibilidade: 1.0
# F1-Score: 0.9908256880733944
# Kappa: 0.9747003994673769

# %%
svc_fpG, svc_vpG, lim5G = roc_curve(y_teste, y_pred_svc)
svc_curva_rocG = roc_auc_score(y_teste,y_pred_svc)

plt.plot(svc_fpG, svc_vpG, marker=".", label="SVC "+str(round(svc_curva_rocG, 2)), color="brown")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
svc_probsG = grid_search.predict_proba(x_teste)[:,1]

svc_fpG, svc_vpG, lim5G = roc_curve(y_teste, svc_probsG)

plt.plot(svc_fpG, svc_vpG, marker=".", label="SVC", color="brown")

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# # Resultado

# %% [markdown]
# ## Normal

# %%
ada_fp, ada_vp, lim1 = roc_curve(y_teste, ada_predict)
gbm_fp, gbm_vp, lim2 = roc_curve(y_teste, gbm_predict)
rf_fp, rf_vp, lim3 = roc_curve(y_teste, rf_predict)
cat_fp, cat_vp, lim4 = roc_curve(y_teste, cat_predict)
svc_fp, svc_vp, lim5 = roc_curve(y_teste, svc_predict)

plt.plot(ada_fp, ada_vp, marker=".", label="AdaBoost "+str(round(ada_curva_roc, 2)), color="red")
plt.plot(gbm_fp, gbm_vp, marker=".", label="GBM "+str(round(gbm_curva_roc, 2)), color="green")
plt.plot(rf_fp, rf_vp, marker=".", label="Random Forest "+str(round(rf_curva_roc, 2)), color="blue")
plt.plot(cat_fp, cat_vp, marker=".", label="CatBoost "+str(round(cat_curva_roc, 2)), color="yellow")
plt.plot(svc_fp, svc_vp, marker=".", label="SVC "+str(round(svc_curva_roc, 2)), color="brown")
plt.plot([0, 1], [0, 1], color='black', linestyle='--')

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
ada_probs = ada_predict_prob[:,1]
gbm_probs = gbm_predict_prob[:,1]
rf_probs = rf_predict_prob[:,1]
cat_probs = cat_predict_prob[:,1]
svc_probs = svc_predict_prob[:,1]

ada_fp, ada_vp, lim1 = roc_curve(y_teste, ada_probs)
gbm_fp, gbm_vp, lim2 = roc_curve(y_teste, gbm_probs)
rf_fp, rf_vp, lim3 = roc_curve(y_teste, rf_probs)
cat_fp, cat_vp, lim4 = roc_curve(y_teste, cat_probs)
svc_fp, svc_vp, lim5 = roc_curve(y_teste, svc_probs)

plt.plot(ada_fp, ada_vp, marker=".", label="AdaBoost", color="red")
plt.plot(gbm_fp, gbm_vp, marker=".", label="GBM", color="green")
plt.plot(rf_fp, rf_vp, marker=".", label="Random Forest", color="blue")
plt.plot(cat_fp, cat_vp, marker=".", label="CatBoost", color="yellow")
plt.plot(svc_fp, svc_vp, marker=".", label="SVC", color="brown")
plt.plot([0, 1], [0, 1], color='black', linestyle='--')

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %% [markdown]
# ## Grid Search

# %%
ada_fpG, ada_vpG, lim1G = roc_curve(y_teste, y_predAda)
gbm_fpG, gbm_vpG, lim2G = roc_curve(y_teste, y_pred_gbm)
rf_fpG, rf_vpG, lim3G = roc_curve(y_teste, y_pred_rf)
cat_fpG, cat_vpG, lim4G = roc_curve(y_teste, y_pred_cat)
svc_fpG, svc_vpG, lim5G = roc_curve(y_teste, y_pred_svc)

plt.plot(ada_fpG, ada_vpG, marker=".", label="AdaBoost "+str(round(ada_curva_rocG, 2)), color="red")
plt.plot(gbm_fpG, gbm_vpG, marker=".", label="GBM "+str(round(gbm_curva_rocG, 2)), color="green")
plt.plot(rf_fpG, rf_vpG, marker=".", label="Random Forest "+str(round(rf_curva_rocG, 2)), color="blue")
plt.plot(cat_fpG, cat_vpG, marker=".", label="CatBoost "+str(round(cat_curva_rocG, 2)), color="yellow")
plt.plot(svc_fpG, svc_vpG, marker=".", label="SVC "+str(round(svc_curva_rocG, 2)), color="brown")
plt.plot([0, 1], [0, 1], color='black', linestyle='--')

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()

# %%
# ada_probs = ada_predict_prob[:,1]
# gbm_probs = gbm_predict_prob[:,1]
# rf_probs = rf_predict_prob[:,1]
# cat_probs = cat_predict_prob[:,1]
# svc_probs = svc_predict_prob[:,1]

ada_fp, ada_vp, lim1 = roc_curve(y_teste, ada_probsG)
gbm_fp, gbm_vp, lim2 = roc_curve(y_teste, gbm_probsG)
rf_fp, rf_vp, lim3 = roc_curve(y_teste, rf_probsG)
cat_fp, cat_vp, lim4 = roc_curve(y_teste, cat_probsG)
svc_fp, svc_vp, lim5 = roc_curve(y_teste, svc_probsG)

plt.plot(ada_fpG, ada_vpG, marker=".", label="AdaBoost", color="red")
plt.plot(gbm_fpG, gbm_vpG, marker=".", label="GBM", color="green")
plt.plot(rf_fpG, rf_vpG, marker=".", label="Random Forest", color="blue")
plt.plot(cat_fpG, cat_vpG, marker=".", label="CatBoost", color="yellow")
plt.plot(svc_fpG, svc_vpG, marker=".", label="SVC", color="brown")
plt.plot([0, 1], [0, 1], color='black', linestyle='--')

plt.xlabel('1- Especificidade')
plt.ylabel('Sensibilidade')

plt.legend()

plt.show()
